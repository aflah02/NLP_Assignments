# %%
import pandas as pd
import numpy as np
import pickle
from preprocess_text import *
from bigrams import *
from smoothers import *
from LanguageModels import *

# %%
df = pd.read_csv('A1_dataset.csv')

# %%
# text = df['TEXT'].to_list()
# def preprocess_text(text):
#     text = lowercase_text(text)
#     text = remove_url_html(text)
#     text = remove_users(text)
#     text = remove_punctuations(text)
#     text = remove_whitespaces(text)
#     text = tokenization(text)
#     text = spelling_correction(text, 'autocorrect_full')
#     text = remove_alphanum(text)
#     return text
# df['preprocessed_text'] = df['TEXT'].progress_apply(preprocess_text)
# preprocess_text = df['preprocessed_text'].to_list()
# df.to_csv('preprocessed_A1.csv', index=False)

# %%
df = pd.read_csv('preprocessed_A1.csv')
preprocess_text = df['preprocessed_text'].to_list()
for i in range(len(preprocess_text)):
    preprocess_text[i] = eval(preprocess_text[i])

# %%
unigram_counts = {}
for sentence in preprocess_text:
    for word in sentence:
        if word in unigram_counts:
            unigram_counts[word] += 1
        else:
            unigram_counts[word] = 1

# %%
unigram_probs = {}
scale_factor = sum(unigram_counts.values())
for word in unigram_counts:
    unigram_probs[word] = unigram_counts[word] / scale_factor

# %%
len(unigram_counts)
# Out:
# 6952

# %% [markdown]
# # Saving Bigrams with Smoothing

# %%
bigram_wrapper = Bigrams(preprocess_text)
bigrams = bigram_wrapper.get_bigrams()
vocab_len = bigram_wrapper.vocab_len

with open('bigram_model_dumps/bigram_wrapper.pickle', 'wb') as f:
    pickle.dump(bigram_wrapper, f)

# %%
# load bigram_wrapper
# with open('bigram_wrapper.pickle', 'rb') as f:
#     bigram_wrapper = pickle.load(f)

# bigrams = bigram_wrapper.get_bigrams()
# vocab_len = bigram_wrapper.vocab_len

# %%
smoother = LMSmoothers(bigrams, vocab_len, unigram_counts=unigram_counts, unigrams_probs=unigram_probs)
laplace_smoothed_bigrams = smoother.laplace()
# add_5_smoothed_bigrams = smoother.add_k(5)
# add_5_with_unigram_prior_smoothed_bigrams = smoother.add_k_with_unigram_prior(5)

# %%
with open('bigram_model_dumps/laplace_smoothed_bigrams.pickle', 'wb') as handle:
    pickle.dump(laplace_smoothed_bigrams, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('bigram_model_dumps/add_5_smoothed_bigrams.pickle', 'wb') as handle:
#     pickle.dump(add_5_smoothed_bigrams, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('bigram_model_dumps/add_5_with_unigram_prior_smoothed_bigrams.pickle', 'wb') as handle:
#     pickle.dump(add_5_with_unigram_prior_smoothed_bigrams, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Creating BiGram Models

# %%
with open('bigram_model_dumps/laplace_smoothed_bigrams.pickle', 'rb') as handle:
    laplace_smoothed_bigrams = pickle.load(handle)

# with open('bigram_model_dumps/add_5_smoothed_bigrams.pickle', 'rb') as handle:
#     add_5_smoothed_bigrams = pickle.load(handle)

# with open('bigram_model_dumps/add_5_with_unigram_prior_smoothed_bigrams.pickle', 'rb') as handle:
#     add_5_with_unigram_prior_smoothed_bigrams = pickle.load(handle)

# %%
# Load Negative Prompts
with open('Pos Neg Prompts/neg_250_vader.txt', 'rb') as handle:
    neg_prompts = handle.readlines()

for i in range(len(neg_prompts)):
    neg_prompts[i] = neg_prompts[i].decode('utf-8').strip()

# %%
# clear the file
open('generated_sentences/neg_vader_textblob.txt', 'w').close()

# %%
def append_to_file(filename, text1, text2):
    with open(filename, 'a') as f:
        f.write(text1 + " " + text2 + '\n')

# %%
ls_neg_gen = []
lm = LanguageModel(laplace_smoothed_bigrams, unigram_probs, "vader", False, False, True, repetition_penalty=0.2, normalizebyPerplexity=False, sentiment_scale_factor=1)
for p in neg_prompts:
    sentence_neg = lm.generate_text([p], sentiment=-1, length=10)
    print("Negative: {}".format(sentence_neg))
    ppl = lm.computePerplexity(sentence_neg)
    print("Negative Perplexity: {}".format(ppl))
    ls_neg_gen.append((sentence_neg, ppl))
    append_to_file('generated_sentences/neg_vader_textblob.txt', " ".join(sentence_neg), str(ppl))
# Out:
# Negative: ['raping', 'kill', 'hell', 'yeah', 'killed', 'the', 'tragedy', 'slavery', 'evil', 'shittiest']
# Negative Perplexity: 5530.273308398864
# Negative: ['slavery', 'killed', 'tea', 'so', 'raping', 'nick', 'kill', 'shittiest', 'tragedy', 'killing']
# Negative Perplexity: 5678.976343893674
# Negative: ['kill', 'me', 'raping', 'nick', 'said', 'he', 'died', 'weeks', 'killed', 'im']
# Negative Perplexity: 3711.9087780364766
# Negative: ['hell', 'slavery', 'raping', 'tragedy', 'utter', 'horrific', 'shittiest', 'kill', 'killing', 'me']
# Negative Perplexity: 5425.130021503058
# Negative: ['killed', 'the', 'shittiest', 'hell', 'yeah', 'slavery', 'and', 'horrific', 'tragedy', 'raping']
# Negative Perplexity: 4865.801517988086
# Negative: ['killing', 'raping', 'nick', 'said', 'hell', 'kill', 'me', 'tragedy', 'killed', 'the']
# Negative Perplexity: 4752.8121752894085
# Negative: ['evil', 'is', 'hell', 'slavery', 'killed', 'the', 'dead', 'kill', 'raping', 'nick']
# Negative Perplexity: 4714.020036193244
# Negative: ['horrific', 'ended', 'slavery', 'killed', 'tea', 'i', 'hate', 'hell', 'kill', 'myself']
# Negative Perplexity: 3825.0589576306993
# Negative: ['tragedy', 'raping', 'kill', 'hell', 'slavery', 'and', 'shittiest', 'killed', 'tea', 'i']
# Negative Perplexity: 5710.945287491296
# Negative: ['shittiest', 'hell', 'raping', 'kill', 'slavery', 'and', 'horrific', 'evil', 'and', 'tragedy']
# Negative Perplexity: 6185.589556136217
# Negative: ['dead', 'hell', 'killed', 'raping', 'horrific', 'killing', 'slavery', 'kill', 'me', 'shittiest']
# Negative Perplexity: 6270.472474763032
# Negative: ['devastating', 'see', 'you', 'slavery', 'raping', 'nick', 'kill', 'me', 'tragedy', 'utter']
# Negative Perplexity: 3800.872974119749
# Negative: ['whore', 'slavery', 'and', 'killed', 'a', 'raping', 'killing', 'me', 'tragedy', 'utter']
# Negative Perplexity: 4867.385114784881
# Negative: ['hated', 'each', 'raping', 'hell', 'killed', 'slavery', 'tragedy', 'arms', 'horrific', 'kill']
# Negative Perplexity: 6055.461594359095
# Negative: ['pissed', 'at', 'the', 'slavery', 'killed', 'tea', 'so', 'kill', 'me', 'raping']
# Negative Perplexity: 3421.1180471202765
# Negative: ['doomed', 'hell', 'yeah', 'i', 'hate', 'it', 'was', 'slavery', 'and', 'kill']
# Negative Perplexity: 1771.4994525188984
# Negative: ['vile', 'hell', 'slavery', 'raping', 'nick', 'to', 'kill', 'chris', 'brown', 'horrific']
# Negative Perplexity: 4679.067114895433
# Negative: ['violence', 'hell', 'kill', 'me', 'raping', 'nick', 'slavery', 'horrific', 'ended', 'shittiest']
# Negative Perplexity: 5456.881437930761
# Negative: ['worst', 'dreams', 'of', 'the', 'kill', 'chris', 'wants', 'to', 'raping', 'hell']
# Negative Perplexity: 2759.598990863819
# Negative: ['crisis', 'hell', 'kill', 'chris', 'to', 'raping', 'killed', 'im', 'not', 'tragedy']
# Negative Perplexity: 3970.113778433144
# Negative: ['infuriated', 'and', 'kill', 'me', 'raping', 'slavery', 'horrific', 'killed', 'a', 'tragedy']
# Negative Perplexity: 5590.755434754573
# Negative: ['death', 'lovely', 'slavery', 'and', 'raping', 'nick', 'to', 'killed', 'the', 'horrific']
# Negative Perplexity: 4816.351724832201
# Negative: ['die', 'because', 'you', 'slavery', 'and', 'kill', 'myself', 'horrific', 'hell', 'yeah']
# Negative Perplexity: 4404.800663680809
# Negative: ['torture', 'me', 'killed', 'raping', 'slavery', 'killing', 'kill', 'myself', 'shittiest', 'tragedy']
# Negative Perplexity: 6092.387697906542
# Negative: ['havoc', 'raping', 'nick', 'paid', 'me', 'slavery', 'tragedy', 'killed', 'im', 'not']
# Negative Perplexity: 3638.4704098765624
# Negative: ['war', 'phn', 'slavery', 'and', 'raping', 'killed', 'im', 'not', 'kill', 'me']
# Negative Perplexity: 3525.327682651279
# Negative: ['drowned', 'kill', 'me', 'raping', 'hell', 'killed', 'the', 'horrific', 'killing', 'all']
# Negative Perplexity: 5185.303467494762
# Negative: ['wtf', 'kill', 'me', 'hell', 'tragedy', 'raping', 'slavery', 'killing', 'killed', 'im']
# Negative Perplexity: 5849.549713174019
# Negative: ['bitch', 'loljkmines', 'slavery', 'kill', 'hell', 'killed', 'raping', 'shittiest', 'evil', 'me']
# Negative Perplexity: 6055.461619378147
# Negative: ['cruel', 'kill', 'me', 'killed', 'the', 'raping', 'slavery', 'hell', 'tragedy', 'utter']
# Negative Perplexity: 5184.930839584273
# Negative: ['bullshit', 'slavery', 'kill', 'me', 'horrific', 'ended', 'up', 'killing', 'raping', 'killed']
# Negative Perplexity: 5257.033402982059
# Negative: ['ruin', 'your', 'kill', 'chris', 'rocker', 'tragedy', 'hell', 'slavery', 'raping', 'horrific']
# Negative Perplexity: 5664.390055948817
# Negative: ['hate', 'raping', 'nick', 'to', 'hell', 'tragedy', 'slavery', 'kill', 'me', 'evil']
# Negative Perplexity: 5567.7514725308165
# Negative: ['drown', 'kill', 'me', 'horrific', 'raping', 'killed', 'a', 'hell', 'tragedy', 'killing']
# Negative Perplexity: 5929.469603364744
# Negative: ['chaos', 'slavery', 'and', 'hell', 'killed', 'a', 'horrific', 'raping', 'kill', 'me']
# Negative Perplexity: 5559.023735110929
# Negative: ['anger', 'hell', 'raping', 'tragedy', 'kill', 'me', 'killing', 'all', 'horrific', 'ended']
# Negative Perplexity: 5473.989888797988
# Negative: ['depression', 'slavery', 'and', 'hell', 'raping', 'nick', 'kill', 'killed', 'im', 'tragedy']
# Negative Perplexity: 5747.390132213505
# Negative: ['retarded', 'hell', 'killed', 'a', 'horrific', 'raping', 'killing', 'me', 'evil', 'slavery']
# Negative Perplexity: 5532.629283922779
# Negative: ['terrifying', 'hell', 'yeah', 'i', 'raping', 'tragedy', 'utter', 'slavery', 'kill', 'me']
# Negative Perplexity: 4027.731129106434
# Negative: ['scam', 'raping', 'killed', 'tea', 'so', 'kill', 'me', 'horrific', 'ended', 'up']
# Negative Perplexity: 4585.365105205743
# Negative: ['pathetic', 'kill', 'me', 'killed', 'the', 'raping', 'slavery', 'and', 'killing', 'mee']
# Negative Perplexity: 4889.309866630633
# Negative: ['insanity', 'raping', 'hell', 'kill', 'me', 'killed', 'tea', 'yet', 'ill', 'horrific']
# Negative Perplexity: 4898.663836403096
# Negative: ['shit', 'died', 'in', 'raping', 'hell', 'yeah', 'kill', 'me', 'killed', 'tea']
# Negative Perplexity: 4605.636533366513
# Negative: ['rob', 'ss', 'raping', 'hell', 'tragedy', 'slavery', 'killing', 'me', 'shittiest', 'killed']
# Negative Perplexity: 5457.038258381417
# Negative: ['nasty', 'raping', 'hell', 'kill', 'slavery', 'tragedy', 'utter', 'killed', 'the', 'shittiest']
# Negative Perplexity: 5367.987475041433
# Negative: ['died', 'in', 'slavery', 'killed', 'tea', 'i', 'hell', 'raping', 'tragedy', 'killing']
# Negative Perplexity: 5841.44675696539
# Negative: ['po', 'good', 'hell', 'yeah', 'slavery', 'kill', 'me', 'killed', 'im', 'dead']
# Negative Perplexity: 4429.695028510189
# Negative: ['wars', 'me', 'kill', 'chris', 'wants', 'to', 'hell', 'raping', 'slavery', 'killed']
# Negative Perplexity: 4451.2644118621165
# Negative: ['crappy', 'ipod', 'for', 'slavery', 'hell', 'kill', 'me', 'shittiest', 'raping', 'nick']
# Negative Perplexity: 5134.4591772412
# Negative: ['terribly', 'slow', 'admit', 'lol', 'kill', 'slavery', 'killed', 'im', 'shittiest', 'tragedy']
# Negative Perplexity: 5317.298520130228
# Negative: ['robber', 'hell', 'killed', 'im', 'slavery', 'and', 'kill', 'raping', 'nick', 'he']
# Negative Perplexity: 5362.504608588294
# Negative: ['starved', 'killed', 'a', 'slavery', 'hell', 'yeah', 'tragedy', 'arms', 'legs', 'a']
# Negative Perplexity: 4793.138317872828
# Negative: ['ban', 'hell', 'slavery', 'and', 'killed', 'im', 'dead', 'horrific', 'killing', 'it']
# Negative Perplexity: 5150.606286996574
# Negative: ['cheating', 'me', 'slavery', 'killed', 'tea', 'la', 'kill', 'chris', 'raping', 'hell']
# Negative Perplexity: 5302.8195013259
# Negative: ['bad', 'slavery', 'and', 'hell', 'raping', 'kill', 'shittiest', 'venue', 'in', 'killing']
# Negative Perplexity: 5761.0393680188945
# Negative: ['ass', 'to', 'slavery', 'raping', 'tragedy', 'arms', 'legs', 'playing', 'with', 'the']
# Negative Perplexity: 3313.824762273795
# Negative: ['horrible', 'and', 'kill', 'me', 'raping', 'slavery', 'and', 'horrific', 'ended', 'up']
# Negative Perplexity: 4659.757066314999
# Negative: ['fuck', 'my', 'raping', 'kill', 'me', 'horrific', 'tragedy', 'arms', 'slavery', 'hell']
# Negative Perplexity: 5518.219747107076
# Negative: ['fail', 'of', 'hell', 'killed', 'a', 'slavery', 'and', 'kill', 'myself', 'tragedy']
# Negative Perplexity: 5075.911593565375
# Negative: ['kills', 'hell', 'raping', 'killed', 'slavery', 'kill', 'shittiest', 'venue', 'in', 'killing']
# Negative Perplexity: 6104.294286453927
# Negative: ['suffer', 'hell', 'killed', 'im', 'kill', 'chris', 'raping', 'shittiest', 'killing', 'it']
# Negative Perplexity: 5686.7366570583945
# Negative: ['poison', 'hell', 'raping', 'killed', 'im', 'dead', 'tired', 'but', 'slavery', 'kill']
# Negative Perplexity: 4674.54701147901
# Negative: ['bastard', 'raping', 'nick', 'to', 'slavery', 'kill', 'chris', 'hell', 'shittiest', 'venue']
# Negative Perplexity: 5374.682117431699
# Negative: ['prisoner', 'of', 'raping', 'hell', 'killed', 'the', 'kill', 'myself', 'horrific', 'ended']
# Negative Perplexity: 5043.517023403233
# Negative: ['stupid', 'slavery', 'killed', 'raping', 'nick', 'he', 'was', 'horrific', 'kill', 'hell']
# Negative Perplexity: 4749.876051893812
# Negative: ['hurt', 'now', 'raping', 'hell', 'tragedy', 'killed', 'the', 'horrific', 'shittiest', 'kill']
# Negative Perplexity: 5772.911642022417
# Negative: ['sorrow', 'killed', 'the', 'hell', 'slavery', 'and', 'killing', 'me', 'raping', 'tragedy']
# Negative Perplexity: 4162.9429829246465
# Negative: ['frustrated', 'kill', 'raping', 'killed', 'im', 'not', 'hell', 'shittiest', 'slavery', 'and']
# Negative Perplexity: 4172.902456402072
# Negative: ['punish', 'kill', 'raping', 'tragedy', 'arms', 'for', 'a', 'killing', 'me', 'slavery']
# Negative Perplexity: 3450.3858302174845
# Negative: ['casualty', 'slavery', 'and', 'kill', 'chris', 'raping', 'tragedy', 'horrific', 'killing', 'me']
# Negative Perplexity: 5115.666999557051
# Negative: ['thief', 'or', 'something', 'raping', 'hell', 'tragedy', 'slavery', 'killing', 'me', 'evil']
# Negative Perplexity: 4440.430053459798
# Negative: ['loser', 'for', 'slavery', 'killed', 'a', 'raping', 'nick', 'to', 'shittiest', 'venue']
# Negative Perplexity: 5125.768151645847
# Negative: ['revenge', 'hell', 'slavery', 'kill', 'me', 'tragedy', 'killed', 'the', 'raping', 'shittiest']
# Negative Perplexity: 5557.071278952446
# Negative: ['lying', 'hell', 'raping', 'nick', 'he', 'kill', 'myself', 'killed', 'a', 'shittiest']
# Negative Perplexity: 5353.175495206566
# Negative: ['trapped', 'kill', 'me', 'killed', 'im', 'slavery', 'and', 'tragedy', 'arms', 'for']
# Negative Perplexity: 4832.076115870458
# Negative: ['sufferers', 'kill', 'chris', 'rocker', 'raping', 'slavery', 'horrific', 'killing', 'it', 'killed']
# Negative Perplexity: 5697.484412612357
# Negative: ['terror', 'raping', 'hell', 'kill', 'myself', 'killed', 'im', 'slavery', 'horrific', 'evil']
# Negative Perplexity: 6096.2919594149225
# Negative: ['sick', 'hell', 'yeah', 'i', 'slavery', 'and', 'raping', 'kill', 'shittiest', 'venue']
# Negative Perplexity: 4241.689394446328
# Negative: ['pain', 'slavery', 'kill', 'hell', 'yeah', 'shittiest', 'venue', 'in', 'the', 'killed']
# Negative Perplexity: 3457.2936060111447
# Negative: ['failed', 'on', 'my', 'killed', 'tea', 'la', 'the', 'shittiest', 'venue', 'hell']
# Negative Perplexity: 3053.3522627783873
# Negative: ['panic', 'attacks', 'kill', 'me', 'raping', 'hell', 'horrific', 'ended', 'up', 'killed']
# Negative Perplexity: 4905.619894033033
# Negative: ['ugly', 'and', 'raping', 'hell', 'killed', 'the', 'dead', 'tragedy', 'slavery', 'shittiest']
# Negative Perplexity: 5063.456430637586
# Negative: ['rejected', 'raping', 'nick', 'said', 'hell', 'slavery', 'and', 'kill', 'chris', 'wants']
# Negative Perplexity: 4972.737335546998
# Negative: ['idiot', 'damn', 'slavery', 'and', 'hell', 'killed', 'a', 'kill', 'chris', 'brown']
# Negative Perplexity: 5042.0534159476265
# Negative: ['dumb', 'raping', 'nick', 'to', 'slavery', 'kill', 'me', 'killed', 'a', 'shittiest']
# Negative Perplexity: 5262.552527183705
# Negative: ['depressed', 'raping', 'hell', 'kill', 'me', 'slavery', 'horrific', 'tragedy', 'killing', 'killed']
# Negative Perplexity: 6268.85139802406
# Negative: ['angry', 'with', 'my', 'raping', 'nick', 'he', 'kill', 'hell', 'slavery', 'tragedy']
# Negative Perplexity: 4016.1045250597313
# Negative: ['disappointment', 'kill', 'myself', 'raping', 'nick', 'paid', 'slavery', 'killed', 'hell', 'shittiest']
# Negative Perplexity: 5652.135664530741
# Negative: ['failing', 'tomorrowtoday', 'hopefully', 'raping', 'slavery', 'and', 'killing', 'all', 'hell', 'yeah']
# Negative Perplexity: 4789.631916510118
# Negative: ['failure', 'then', 'kill', 'me', 'killed', 'im', 'not', 'shittiest', 'slavery', 'tragedy']
# Negative Perplexity: 3765.6218743457534
# Negative: ['prison', 'slavery', 'and', 'hell', 'killed', 'the', 'shittiest', 'kill', 'raping', 'tragedy']
# Negative Perplexity: 5425.553124788438
# Negative: ['hating', 'it', 'hell', 'raping', 'nick', 'said', 'slavery', 'horrific', 'killing', 'mee']
# Negative Perplexity: 5318.2318200850605
# Negative: ['unjust', 'raping', 'killed', 'the', 'hell', 'kill', 'myself', 'slavery', 'and', 'shittiest']
# Negative Perplexity: 4620.7140516763775
# Negative: ['dick', 'raping', 'nick', 'paid', 'work', 'killed', 'the', 'shittiest', 'kill', 'myself']
# Negative Perplexity: 4370.323191164397
# Negative: ['scare', 'dream', 'slavery', 'kill', 'me', 'tragedy', 'hell', 'yeah', 'shittiest', 'raping']
# Negative Perplexity: 5246.355728001657
# Negative: ['wasted', 'and', 'slavery', 'and', 'hell', 'tragedy', 'kill', 'chris', 'brown', 'killed']
# Negative Perplexity: 5385.4105096171315
# Negative: ['fear', 'were', 'slavery', 'killed', 'the', 'kill', 'myself', 'tragedy', 'utter', 'hell']
# Negative Perplexity: 5016.245825498198
# Negative: ['screwed', 'slavery', 'kill', 'me', 'raping', 'hell', 'tragedy', 'utter', 'tragedy', 'arms']
# Negative Perplexity: 5091.377244245685
# Negative: ['mad', 'the', 'raping', 'hell', 'slavery', 'killed', 'the', 'horrific', 'kill', 'me']
# Negative Perplexity: 5249.2538155786215
# Negative: ['scary', 'kill', 'chris', 'to', 'horrific', 'ended', 'early', 'to', 'slavery', 'killed']
# Negative Perplexity: 4582.5260471830625
# Negative: ['infected', 'killed', 'raping', 'kill', 'chris', 'slavery', 'tragedy', 'killing', 'me', 'devastating']
# Negative Perplexity: 5456.881911123356
# Negative: ['damage', 'killed', 'tea', 'i', 'raping', 'hell', 'yeah', 'i', 'kill', 'chris']
# Negative Perplexity: 4013.673871133622
# Negative: ['miserable', 'kill', 'me', 'slavery', 'killed', 'a', 'hell', 'tragedy', 'raping', 'nick']
# Negative Perplexity: 5532.470325503465
# Negative: ['stolen', 'im', 'slavery', 'killed', 'raping', 'nick', 'kill', 'myself', 'horrific', 'hell']
# Negative Perplexity: 5687.387998620618
# Negative: ['bomb', 'you', 'hell', 'slavery', 'and', 'tragedy', 'utter', 'horrific', 'ended', 'killed']
# Negative Perplexity: 5383.266011117433
# Negative: ['enemies', 'hell', 'yeah', 'raping', 'kill', 'me', 'tragedy', 'arms', 'for', 'slavery']
# Negative Perplexity: 4935.23773274958
# Negative: ['fools', 'slavery', 'hell', 'kill', 'myself', 'horrific', 'killed', 'raping', 'killing', 'mee']
# Negative Perplexity: 6057.8088616832965
# Negative: ['steal', 'slavery', 'and', 'hell', 'tragedy', 'raping', 'horrific', 'killed', 'kill', 'chris']
# Negative Perplexity: 6120.2237246550185
# Negative: ['shameful', 'raping', 'kill', 'chris', 'wants', 'killed', 'a', 'slavery', 'tragedy', 'utter']
# Negative Perplexity: 5344.607190537818
# Negative: ['violate', 'was', 'slavery', 'hell', 'tragedy', 'raping', 'kill', 'horrific', 'ended', 'up']
# Negative Perplexity: 5448.379399290063
# Negative: ['haters', 'kill', 'slavery', 'killed', 'tea', 'so', 'hell', 'tragedy', 'arms', 'legs']
# Negative Perplexity: 5299.585963051372
# Negative: ['grief', 'i', 'raping', 'kill', 'chris', 'wants', 'to', 'hell', 'horrific', 'ended']
# Negative Perplexity: 4233.775927280951
# Negative: ['sad', 'killed', 'the', 'slavery', 'kill', 'myself', 'in', 'horrific', 'ended', 'up']
# Negative Perplexity: 4226.594503592962
# Negative: ['wrong', 'with', 'kill', 'raping', 'tragedy', 'arms', 'legs', 'so', 'hell', 'yeah']
# Negative Perplexity: 4274.047591805759
# Negative: ['poor', 'hell', 'yeah', 'killed', 'tea', 'that', 'horrific', 'ended', 'up', 'killing']
# Negative Perplexity: 4581.545241481706
# Negative: ['cry', 'raping', 'hell', 'yeah', 'horrific', 'ended', 'early', 'tomorrow', 'killed', 'tea']
# Negative Perplexity: 4420.518650287054
# Negative: ['hurts', 'raping', 'hell', 'kill', 'me', 'slavery', 'horrific', 'ended', 'early', 'killed']
# Negative Perplexity: 5460.406984736782
# Negative: ['badly', 'slavery', 'and', 'hell', 'yeah', 'i', 'killed', 'raping', 'nick', 'said']
# Negative Perplexity: 3956.1049766259507
# Negative: ['terrible', 'phases', 'kill', 'raping', 'slavery', 'and', 'killed', 'the', 'hell', 'shittiest']
# Negative Perplexity: 4619.189204392983
# Negative: ['disappointed', 'that', 'kill', 'myself', 'slavery', 'raping', 'tragedy', 'horrific', 'ended', 'killed']
# Negative Perplexity: 5681.6048015363895
# Negative: ['worse', 'rates', 'today', 'hell', 'raping', 'nick', 'he', 'slavery', 'kill', 'me']
# Negative Perplexity: 4739.703356822551
# Negative: ['gross', 'but', 'i', 'hell', 'slavery', 'and', 'kill', 'raping', 'horrific', 'killing']
# Negative Perplexity: 4100.595929755454
# Negative: ['shame', 'kill', 'myself', 'slavery', 'hell', 'horrific', 'ended', 'early', 'today', 'shittiest']
# Negative Perplexity: 4933.024781493805
# Negative: ['crying', 'i', 'slavery', 'kill', 'me', 'horrific', 'killed', 'the', 'dead', 'tired']
# Negative Perplexity: 4029.9546819247958
# Negative: ['broken', 'frm', 'slavery', 'killed', 'the', 'shittiest', 'horrific', 'ended', 'kill', 'hell']
# Negative Perplexity: 5007.7898917748835
# Negative: ['fake', 'kristen', 'stewart', 'i', 'hell', 'yeah', 'i', 'hate', 'slavery', 'kill']
# Negative Perplexity: 2839.437158856253
# Negative: ['attack', 'but', 'hell', 'raping', 'nick', 'paid', 'in', 'kill', 'myself', 'shittiest']
# Negative Perplexity: 4650.77459570696
# Negative: ['shattered', 'by', 'kill', 'me', 'slavery', 'hell', 'yeah', 'horrific', 'killed', 'the']
# Negative Perplexity: 4570.681636057422
# Negative: ['ruined', 'the', 'raping', 'killed', 'slavery', 'hell', 'killing', 'all', 'horrific', 'tragedy']
# Negative Perplexity: 6185.352792340512
# Negative: ['ashamed', 'for', 'a', 'slavery', 'kill', 'myself', 'in', 'the', 'shittiest', 'venue']
# Negative Perplexity: 1979.9981608277064
# Negative: ['accident', 'used', 'slavery', 'and', 'kill', 'me', 'hell', 'tragedy', 'arms', 'teddy']
# Negative Perplexity: 4802.883678650596
# Negative: ['choked', 'raping', 'killed', 'the', 'hell', 'yeah', 'kill', 'me', 'tragedy', 'slavery']
# Negative Perplexity: 4243.049211800822
# Negative: ['oppressed', 'hell', 'raping', 'tragedy', 'slavery', 'killed', 'the', 'shittiest', 'venue', 'kill']
# Negative Perplexity: 5367.601574838174
# Negative: ['unpleasant', 'raping', 'kill', 'me', 'slavery', 'horrific', 'killed', 'a', 'hell', 'killing']
# Negative Perplexity: 5929.299071746164
# Negative: ['rude', 'to', 'raping', 'hell', 'tragedy', 'arms', 'kill', 'me', 'slavery', 'killed']
# Negative Perplexity: 5564.081822558227
# Negative: ['jealous', 'i', 'killed', 'a', 'tragedy', 'utter', 'hell', 'horrific', 'ended', 'up']
# Negative Perplexity: 4581.56378140365
# Negative: ['appalled', 'slavery', 'hell', 'killed', 'the', 'raping', 'tragedy', 'utter', 'tragedy', 'horrific']
# Negative Perplexity: 5367.678757096785
# Negative: ['irritated', 'when', 'i', 'killed', 'raping', 'nick', 'he', 'was', 'hell', 'kill']
# Negative Perplexity: 3189.0545276648677
# Negative: ['frustrations', 'raping', 'kill', 'myself', 'in', 'hell', 'yeah', 'i', 'killed', 'slavery']
# Negative Perplexity: 3947.1675207760654
# Negative: ['unfortunate', 'slavery', 'and', 'raping', 'nick', 'kill', 'myself', 'horrific', 'tragedy', 'hell']
# Negative Perplexity: 5711.435230599023
# Negative: ['threatened', 'hell', 'killed', 'tea', 'so', 'sad', 'horrific', 'raping', 'tragedy', 'arms']
# Negative Perplexity: 4336.995202938099
# Negative: ['forced', 'slavery', 'killed', 'tea', 'la', 'the', 'shittiest', 'horrific', 'kill', 'me']
# Negative Perplexity: 4618.452610472478
# Negative: ['attacking', 'migrants', 'students', 'must', 'be', 'kill', 'me', 'raping', 'slavery', 'and']
# Negative Perplexity: 3926.5523972590354
# Negative: ['sucked', 'but', 'raping', 'nick', 'to', 'kill', 'myself', 'killed', 'the', 'horrific']
# Negative Perplexity: 4169.357892083964
# Negative: ['troubles', 'i', 'raping', 'kill', 'myself', 'slavery', 'and', 'shittiest', 'hell', 'yeah']
# Negative Perplexity: 5247.9518741622005
# Negative: ['irritating', 'life', 'is', 'kill', 'raping', 'killed', 'slavery', 'horrific', 'killing', 'me']
# Negative Perplexity: 4269.503438025231
# Negative: ['attacked', 'slavery', 'and', 'killed', 'the', 'shittiest', 'venue', 'kill', 'me', 'killing']
# Negative Perplexity: 4561.493992613159
# Negative: ['awful', 'haha', 'raping', 'nick', 'said', 'killed', 'a', 'kill', 'chris', 'wants']
# Negative Perplexity: 4661.71692938092
# Negative: ['heartbreaking', 'raping', 'nick', 'he', 'was', 'kill', 'chris', 'wants', 'slavery', 'and']
# Negative Perplexity: 3857.9873103810187
# Negative: ['beating', 'hell', 'raping', 'nick', 'he', 'slavery', 'tragedy', 'killed', 'the', 'killing']
# Negative Perplexity: 5374.741100162045
# Negative: ['banned', 'was', 'hell', 'yeah', 'raping', 'nick', 'slavery', 'kill', 'chris', 'rocker']
# Negative Perplexity: 4748.252328478665
# Negative: ['cheat', 'day', 'raping', 'hell', 'yeah', 'horrific', 'tragedy', 'killed', 'slavery', 'evil']
# Negative Perplexity: 5837.264452487842
# Negative: ['dire', 'hell', 'yeah', 'raping', 'kill', 'myself', 'tragedy', 'slavery', 'and', 'killing']
# Negative Perplexity: 5490.694223627568
# Negative: ['scared', 'slavery', 'raping', 'nick', 'said', 'horrific', 'ended', 'early', 'to', 'shittiest']
# Negative Perplexity: 4495.72149925615
# Negative: ['tired', 'kill', 'slavery', 'and', 'tragedy', 'raping', 'nick', 'paid', 'in', 'the']
# Negative Perplexity: 3332.011800558991
# Negative: ['block', 'away', 'from', 'the', 'slavery', 'and', 'raping', 'hell', 'kill', 'chris']
# Negative Perplexity: 3469.121292703253
# Negative: ['bloody', 'board', 'slavery', 'hell', 'yeah', 'i', 'killed', 'the', 'kill', 'myself']
# Negative Perplexity: 3718.7439016304543
# Negative: ['weak', 'in', 'hell', 'raping', 'tragedy', 'kill', 'myself', 'horrific', 'ended', 'shittiest']
# Negative Perplexity: 5697.47013030087
# Negative: ['attacks', 'hell', 'killed', 'raping', 'nick', 'said', 'kill', 'me', 'slavery', 'killing']
# Negative Perplexity: 5458.841185416177
# Negative: ['sadness', 'raping', 'nick', 'paid', 'slavery', 'tragedy', 'arms', 'for', 'the', 'kill']
# Negative Perplexity: 3432.50520986408
# Negative: ['freak', 'slavery', 'raping', 'nick', 'kill', 'me', 'killing', 'it', 'horrific', 'tragedy']
# Negative Perplexity: 5503.428846417782
# Negative: ['hates', 'hates', 'hates', 'thursday', 'thursday', 'thursday', 'slavery', 'raping', 'nick', 'paid']
# Negative Perplexity: 3641.1577507313937
# Negative: ['annoy', 'kill', 'chris', 'brown', 'go', 'hell', 'yeah', 'i', 'tragedy', 'utter']
# Negative Perplexity: 3663.0428964174776
# Negative: ['worry', 'i', 'raping', 'slavery', 'killed', 'the', 'shittiest', 'tragedy', 'kill', 'chris']
# Negative Perplexity: 5135.073559299058
# Negative: ['ruins', 'hell', 'yeah', 'slavery', 'tragedy', 'killed', 'tea', 'la', 'horrific', 'shittiest']
# Negative Perplexity: 5431.65922587429
# Negative: ['mourning', 'for', 'raping', 'nick', 'said', 'killed', 'a', 'slavery', 'killing', 'it']
# Negative Perplexity: 5029.034819542005
# Negative: ['painful', 'maths', 'raping', 'nick', 'said', 'slavery', 'and', 'hell', 'yeah', 'i']
# Negative Perplexity: 3600.4062441946576
# Negative: ['dirty', 'hell', 'yeah', 'i', 'kill', 'slavery', 'killed', 'the', 'tragedy', 'horrific']
# Negative Perplexity: 4271.653570311849
# Negative: ['meaningless', 'hell', 'killed', 'im', 'slavery', 'raping', 'nick', 'paid', 'work', 'tragedy']
# Negative Perplexity: 5318.432193454546
# Negative: ['suck', 'kill', 'me', 'killed', 'a', 'horrific', 'ended', 'raping', 'tragedy', 'utter']
# Negative Perplexity: 5161.829210252034
# Negative: ['abandon', 'kill', 'me', 'slavery', 'raping', 'nick', 'to', 'shittiest', 'hell', 'horrific']
# Negative Perplexity: 5563.841760937987
# Negative: ['undesirable', 'raping', 'nick', 'paid', 'work', 'tragedy', 'utter', 'tragedy', 'hell', 'slavery']
# Negative Perplexity: 4930.310315115514
# Negative: ['woes', 'kill', 'myself', 'in', 'the', 'raping', 'slavery', 'tragedy', 'utter', 'tragedy']
# Negative Perplexity: 3131.242574493445
# Negative: ['ill', 'die', 'time', 'to', 'hell', 'slavery', 'tragedy', 'killed', 'the', 'dead']
# Negative Perplexity: 3561.610406097488
# Negative: ['sadly', 'slavery', 'and', 'horrific', 'ended', 'up', 'kill', 'myself', 'raping', 'killing']
# Negative Perplexity: 5134.532084400695
# Negative: ['starving', 'slavery', 'and', 'horrific', 'ended', 'up', 'hell', 'kill', 'me', 'killing']
# Negative Perplexity: 4958.298485902815
# Negative: ['broke', 'stupid', 'alarm', 'slavery', 'hell', 'tragedy', 'killed', 'tea', 'la', 'the']
# Negative Perplexity: 4725.904780781253
# Negative: ['threats', 'ok', 'i', 'killed', 'tea', 'that', 'slavery', 'raping', 'hell', 'killing']
# Negative Perplexity: 4679.063696022585
# Negative: ['stress', 'thats', 'kill', 'chris', 'rocker', 'killed', 'the', 'hell', 'slavery', 'raping']
# Negative Perplexity: 4268.644593673897
# Negative: ['lame', 'but', 'i', 'raping', 'nick', 'said', 'slavery', 'and', 'horrific', 'kill']
# Negative Perplexity: 3570.288472968495
# Negative: ['fakes', 'lol', 'hell', 'killed', 'the', 'shittiest', 'slavery', 'horrific', 'ended', 'up']
# Negative Perplexity: 4497.691642828537
# Negative: ['disheartening', 'raping', 'nick', 'paid', 'me', 'kill', 'me', 'tragedy', 'arms', 'hell']
# Negative Perplexity: 4778.019896645972
# Negative: ['weakness', 'raping', 'nick', 'to', 'killed', 'a', 'killing', 'slavery', 'kill', 'chris']
# Negative Perplexity: 5448.584489317924
# Negative: ['unhappy', 'slavery', 'and', 'horrific', 'ended', 'up', 'killed', 'im', 'dead', 'killing']
# Negative Perplexity: 4629.154102375174
# Negative: ['guilty', 'pleasure', 'raping', 'hell', 'tragedy', 'killed', 'im', 'dead', 'tired', 'slavery']
# Negative Perplexity: 5098.295587393361
# Negative: ['useless', 'hell', 'raping', 'kill', 'me', 'killed', 'slavery', 'shittiest', 'evil', 'and']
# Negative Perplexity: 5848.708825620497
# Negative: ['worries', 'will', 'be', 'kill', 'me', 'killed', 'im', 'hell', 'horrific', 'ended']
# Negative Perplexity: 3508.4064672974873
# Negative: ['beaten', 'slavery', 'and', 'hell', 'yeah', 'killed', 'im', 'kill', 'chris', 'brown']
# Negative Perplexity: 4809.534296451792
# Negative: ['vain', 'hell', 'kill', 'slavery', 'horrific', 'raping', 'killed', 'im', 'dead', 'killing']
# Negative Perplexity: 5853.213524391201
# Negative: ['injury', 'slavery', 'and', 'horrific', 'ended', 'early', 'tomorrow', 'hell', 'raping', 'nick']
# Negative Perplexity: 4647.145534466926
# Negative: ['waste', 'wont', 'be', 'evil', 'and', 'killed', 'raping', 'nick', 'he', 'was']
# Negative Perplexity: 3097.682122214137
# Negative: ['fails', 'me', 'killed', 'im', 'not', 'hell', 'tragedy', 'kill', 'raping', 'shittiest']
# Negative Perplexity: 4197.626702309749
# Negative: ['lies', 'kill', 'myself', 'hell', 'raping', 'nick', 'to', 'slavery', 'and', 'killing']
# Negative Perplexity: 5434.347261182907
# Negative: ['crash', 'den', 'raping', 'hell', 'slavery', 'kill', 'chris', 'rocker', 'killing', 'killed']
# Negative Perplexity: 5650.107896979526
# Negative: ['problem', 'and', 'hell', 'yeah', 'killed', 'a', 'horrific', 'ended', 'raping', 'killing']
# Negative Perplexity: 4986.003786900235
# Negative: ['problems', 'kill', 'myself', 'in', 'killed', 'im', 'slavery', 'tragedy', 'raping', 'hell']
# Negative Perplexity: 5349.621330893523
# Negative: ['blind', 'raping', 'nick', 'paid', 'work', 'kill', 'chris', 'to', 'horrific', 'hell']
# Negative Perplexity: 5026.516270025448
# Negative: ['annoying', 'raping', 'nick', 'said', 'he', 'hell', 'kill', 'myself', 'horrific', 'killed']
# Negative Perplexity: 4928.217208303385
# Negative: ['damn', 'it', 'slavery', 'killed', 'the', 'raping', 'kill', 'chris', 'brown', 'hell']
# Negative Perplexity: 4714.522173243513
# Negative: ['dull', 'girl', 'slavery', 'hell', 'raping', 'nick', 'kill', 'me', 'killed', 'the']
# Negative Perplexity: 4752.606450123274
# Negative: ['insane', 'and', 'slavery', 'kill', 'chris', 'rocker', 'raping', 'killed', 'tea', 'so']
# Negative Perplexity: 4971.16685874537
# Negative: ['fault', 'raping', 'killed', 'im', 'slavery', 'kill', 'myself', 'hell', 'horrific', 'evil']
# Negative Perplexity: 6096.554944110243
# Negative: ['trouble', 'tree', 'got', 'kill', 'me', 'slavery', 'and', 'killed', 'the', 'hell']
# Negative Perplexity: 3892.450884102327
# Negative: ['error', 'raping', 'nick', 'to', 'horrific', 'hell', 'kill', 'me', 'tragedy', 'slavery']
# Negative Perplexity: 5564.001781697529
# Negative: ['stink', 'is', 'kill', 'chris', 'rocker', 'tragedy', 'utter', 'raping', 'nick', 'paid']
# Negative Perplexity: 4627.367785205869
# Negative: ['dumped', 'raping', 'slavery', 'kill', 'killed', 'the', 'dead', 'tragedy', 'utter', 'horrific']
# Negative Perplexity: 5008.652882460801
# Negative: ['lose', 'raping', 'hell', 'killed', 'tea', 'i', 'horrific', 'ended', 'up', 'shittiest']
# Negative Perplexity: 5208.428209660801
# Negative: ['complaints', 'raping', 'nick', 'paid', 'me', 'hell', 'killed', 'a', 'slavery', 'killing']
# Negative Perplexity: 5375.578616921266
# Negative: ['hurting', 'raping', 'slavery', 'killed', 'the', 'hell', 'kill', 'me', 'killing', 'tragedy']
# Negative Perplexity: 4731.296633994319
# Negative: ['injured', 'killed', 'the', 'slavery', 'kill', 'chris', 'rocker', 'tragedy', 'raping', 'nick']
# Negative Perplexity: 4672.433222342436
# Negative: ['hacked', 'slavery', 'kill', 'hell', 'killed', 'the', 'tragedy', 'raping', 'shittiest', 'killing']
# Negative Perplexity: 6166.109717992117
# Negative: ['shocking', 'raping', 'hell', 'kill', 'chris', 'slavery', 'and', 'shittiest', 'tragedy', 'utter']
# Negative Perplexity: 5710.206514770424
# Negative: ['fights', 'on', 'kill', 'slavery', 'killed', 'tea', 'that', 'horrific', 'tragedy', 'killing']
# Negative Perplexity: 5715.0841075963435
# Negative: ['traumatized', 'slavery', 'and', 'kill', 'me', 'hell', 'raping', 'nick', 'killed', 'a']
# Negative Perplexity: 5146.568414377282
# Negative: ['cries', 'raping', 'hell', 'yeah', 'horrific', 'slavery', 'killed', 'the', 'dead', 'shittiest']
# Negative Perplexity: 4815.004442991401
# Negative: ['scream', 'slavery', 'kill', 'myself', 'horrific', 'hell', 'tragedy', 'raping', 'evil', 'is']
# Negative Perplexity: 6057.025268483606
# Negative: ['upset', 'that', 'raping', 'killed', 'slavery', 'kill', 'hell', 'killing', 'it', 'tragedy']
# Negative Perplexity: 6141.338413868869
# Negative: ['crap', 'no', 'hell', 'raping', 'killed', 'slavery', 'tragedy', 'utter', 'tragedy', 'killing']
# Negative Perplexity: 5441.614193229071
# Negative: ['cried', 'when', 'you', 'raping', 'nick', 'he', 'was', 'tragedy', 'slavery', 'and']
# Negative Perplexity: 3236.629558100543
# Negative: ['flu', 'kill', 'slavery', 'hell', 'raping', 'nick', 'killed', 'the', 'dead', 'horrific']
# Negative Perplexity: 5010.020731067918
# Negative: ['battlefield', 'is', 'raping', 'hell', 'tragedy', 'arms', 'teddy', 'in', 'the', 'slavery']
# Negative Perplexity: 3384.006044750154
# Negative: ['losing', 'the', 'killed', 'im', 'raping', 'tragedy', 'arms', 'kill', 'me', 'killing']
# Negative Perplexity: 5218.019409873462
# Negative: ['fight', 'kill', 'slavery', 'hell', 'yeah', 'raping', 'killed', 'im', 'not', 'tragedy']
# Negative Perplexity: 4011.2785846596985
# Negative: ['screaming', 'kill', 'raping', 'nick', 'slavery', 'killed', 'im', 'shittiest', 'killing', 'mee']
# Negative Perplexity: 5685.674501820063
# Negative: ['battle', 'the', 'killed', 'raping', 'hell', 'tragedy', 'utter', 'killing', 'me', 'slavery']
# Negative Perplexity: 5185.3035103732955
# Negative: ['severe', 'kill', 'chris', 'wants', 'to', 'horrific', 'ended', 'hell', 'yeah', 'i']
# Negative Perplexity: 2989.695809043717
# Negative: ['battles', 'are', 'you', 'slavery', 'kill', 'chris', 'to', 'killed', 'the', 'hell']
# Negative Perplexity: 3134.746578105509
# Negative: ['disturbed', 'slavery', 'kill', 'raping', 'killed', 'the', 'dead', 'tired', 'hell', 'horrific']
# Negative Perplexity: 5012.31894168894
# Negative: ['lied', 'slavery', 'kill', 'hell', 'tragedy', 'utter', 'raping', 'killed', 'the', 'horrific']
# Negative Perplexity: 5753.101058960785
# Negative: ['grieve', 'raping', 'slavery', 'kill', 'chris', 'brown', 'killed', 'tea', 'la', 'the']
# Negative Perplexity: 4723.393410469604
# Negative: ['annoyed', 'i', 'kill', 'me', 'slavery', 'raping', 'nick', 'said', 'shittiest', 'horrific']
# Negative Perplexity: 5221.534811556942
# Negative: ['blocking', 'kill', 'me', 'killed', 'the', 'slavery', 'raping', 'killing', 'me', 'hell']
# Negative Perplexity: 4672.3354912054865
# Negative: ['embarrassing', 'kill', 'myself', 'in', 'killed', 'the', 'hell', 'tragedy', 'arms', 'teddy']
# Negative Perplexity: 3743.7404257380936
# Negative: ['smuggle', 'hell', 'kill', 'myself', 'slavery', 'horrific', 'ended', 'up', 'killed', 'im']
# Negative Perplexity: 5080.857042444809
# Negative: ['dump', 'kill', 'slavery', 'tragedy', 'raping', 'nick', 'hell', 'horrific', 'killed', 'tea']
# Negative Perplexity: 6055.374584981992
# Negative: ['grave', 'raping', 'nick', 'he', 'kill', 'myself', 'horrific', 'hell', 'killed', 'the']
# Negative Perplexity: 4926.5896458419165
# Negative: ['funerals', 'kill', 'me', 'killed', 'the', 'shittiest', 'venue', 'raping', 'nick', 'he']
# Negative Perplexity: 4210.86751564002
# Negative: ['shock', 'hell', 'yeah', 'i', 'killed', 'the', 'slavery', 'raping', 'horrific', 'killing']
# Negative Perplexity: 4271.285057804428
# Negative: ['inconvenience', 'kill', 'chris', 'raping', 'slavery', 'and', 'killing', 'me', 'shittiest', 'killed']
# Negative Perplexity: 5145.68108746728
# Negative: ['sore', 'but', 'i', 'raping', 'hell', 'tragedy', 'utter', 'killed', 'tea', 'room']
# Negative Perplexity: 3532.5096205251407
# Negative: ['ridiculous', 'raping', 'nick', 'paid', 'me', 'kill', 'me', 'slavery', 'horrific', 'hell']
# Negative Perplexity: 5120.660396653107
# Negative: ['sucks', 'hell', 'raping', 'kill', 'me', 'shittiest', 'slavery', 'killed', 'tea', 'that']
# Negative Perplexity: 5459.154808595233
# Negative: ['spam', 'it', 'kill', 'slavery', 'killed', 'tea', 'i', 'raping', 'nick', 'said']
# Negative Perplexity: 5086.6740568067435
# Negative: ['doubt', 'they', 'raping', 'nick', 'he', 'hell', 'killed', 'slavery', 'killing', 'kill']
# Negative Perplexity: 5663.776147411647
# Negative: ['exhausted', 'and', 'raping', 'nick', 'said', 'killed', 'im', 'kill', 'chris', 'to']
# Negative Perplexity: 4669.471440301205
# Negative: ['regrets', 'predictor', 'slavery', 'and', 'kill', 'hell', 'raping', 'nick', 'he', 'died']
# Negative Perplexity: 4779.6405396517885
# Negative: ['lazy', 'friday', 'night', 'slavery', 'kill', 'raping', 'killed', 'the', 'dead', 'killing']
# Negative Perplexity: 4272.848671490452
# Negative: ['fighting', 'kill', 'me', 'raping', 'nick', 'paid', 'in', 'the', 'shittiest', 'killed']
# Negative Perplexity: 3023.6382137894707
# Negative: ['mischief', 'slavery', 'raping', 'nick', 'he', 'hell', 'tragedy', 'killed', 'kill', 'myself']
# Negative Perplexity: 5657.13522589474
# Negative: ['lonely', 'now', 'i', 'raping', 'nick', 'to', 'kill', 'myself', 'horrific', 'killed']
# Negative Perplexity: 3489.9141094012343

# %%
# save generated sentences
with open('ls_neg_gen_vader_thread.pickle', 'wb') as handle:
    pickle.dump(ls_neg_gen, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
ls_neg_gen = []
lm = LanguageModel(laplace_smoothed_bigrams, unigram_probs, "vader", True, False, True, repetition_penalty=0.2, sentiment_scale_factor=1e-1)
for p in neg_prompts:
    sentence_neg = lm.generate_text([p], sentiment=-1, length=10)
    print("Negative: {}".format(sentence_neg))
    ppl = lm.computePerplexity(sentence_neg)
    print("Negative Perplexity: {}".format(ppl))
    ls_neg_gen.append((sentence_neg, ppl))
    append_to_file('neg_gen_add_numerator.txt', " ".join(sentence_neg), str(ppl))
# Out:
# Negative: ['raping', 'slavery', 'kill', 'hell', 'kill', 'kill', 'hell', 'killed', 'slavery', 'slavery']
# Negative Perplexity: 6957.298289490414
# Negative: ['slavery', 'kill', 'kill', 'killed', 'killed', 'raping', 'raping', 'killed', 'kill', 'slavery']
# Negative Perplexity: 6955.899475957435
# Negative: ['kill', 'slavery', 'hell', 'kill', 'slavery', 'raping', 'raping', 'hell', 'hell', 'raping']
# Negative Perplexity: 6957.597640824956
# Negative: ['hell', 'killed', 'killed', 'killed', 'raping', 'hell', 'hell', 'raping', 'slavery', 'slavery']
# Negative Perplexity: 6958.597827424857
# Negative: ['killed', 'hell', 'killed', 'kill', 'slavery', 'hell', 'hell', 'hell', 'raping', 'kill']
# Negative Perplexity: 6959.697729014282
# Negative: ['killing', 'hell', 'killed', 'hell', 'hell', 'kill', 'slavery', 'raping', 'kill', 'kill']
# Negative Perplexity: 6958.898010682494
# Negative: ['evil', 'hell', 'slavery', 'slavery', 'hell', 'raping', 'kill', 'hell', 'raping', 'raping']
# Negative Perplexity: 6957.397597763808
# Negative: ['horrific', 'hell', 'raping', 'killed', 'killed', 'slavery', 'slavery', 'hell', 'kill', 'killed']
# Negative Perplexity: 6957.098140009343
# Negative: ['tragedy', 'kill', 'raping', 'hell', 'raping', 'slavery', 'hell', 'slavery', 'raping', 'slavery']
# Negative Perplexity: 6956.098111476809
# Negative: ['shittiest', 'killed', 'slavery', 'raping', 'raping', 'raping', 'raping', 'kill', 'killed', 'hell']
# Negative Perplexity: 6954.499522003902
# Negative: ['dead', 'kill', 'hell', 'hell', 'hell', 'kill', 'raping', 'hell', 'hell', 'raping']
# Negative Perplexity: 6961.897306775258
# Negative: ['devastating', 'raping', 'kill', 'slavery', 'kill', 'kill', 'killed', 'hell', 'raping', 'raping']
# Negative Perplexity: 6955.99882175198
# Negative: ['whore', 'hell', 'kill', 'hell', 'raping', 'raping', 'kill', 'kill', 'kill', 'kill']
# Negative Perplexity: 6957.098312533
# Negative: ['hated', 'kill', 'hell', 'slavery', 'slavery', 'killed', 'raping', 'killed', 'raping', 'killed']
# Negative Perplexity: 6955.798709654357
# Negative: ['pissed', 'hell', 'killed', 'killed', 'raping', 'kill', 'slavery', 'raping', 'killed', 'raping']
# Negative Perplexity: 6956.698806589071
# Negative: ['doomed', 'hell', 'kill', 'hell', 'kill', 'kill', 'kill', 'killed', 'kill', 'hell']
# Negative Perplexity: 6958.09859990063
# Negative: ['vile', 'slavery', 'raping', 'raping', 'slavery', 'kill', 'hell', 'kill', 'kill', 'raping']
# Negative Perplexity: 6955.398847692606
# Negative: ['violence', 'killed', 'kill', 'slavery', 'kill', 'slavery', 'killed', 'raping', 'kill', 'slavery']
# Negative Perplexity: 6955.299510466909
# Negative: ['worst', 'hell', 'raping', 'slavery', 'kill', 'raping', 'slavery', 'hell', 'hell', 'hell']
# Negative Perplexity: 6957.397597763807
# Negative: ['crisis', 'hell', 'slavery', 'kill', 'kill', 'hell', 'kill', 'slavery', 'hell', 'slavery']
# Negative Perplexity: 6957.997801740048
# Negative: ['infuriated', 'killed', 'raping', 'raping', 'hell', 'hell', 'kill', 'raping', 'raping', 'slavery']
# Negative Perplexity: 6956.498071130742
# Negative: ['death', 'hell', 'hell', 'kill', 'hell', 'hell', 'slavery', 'kill', 'slavery', 'hell']
# Negative Perplexity: 6959.297642912991
# Negative: ['die', 'slavery', 'slavery', 'killed', 'kill', 'raping', 'killed', 'raping', 'hell', 'raping']
# Negative Perplexity: 6956.69854790519
# Negative: ['torture', 'slavery', 'raping', 'slavery', 'raping', 'raping', 'slavery', 'kill', 'hell', 'raping']
# Negative Perplexity: 6954.598847803974
# Negative: ['havoc', 'raping', 'killed', 'killed', 'hell', 'kill', 'slavery', 'killed', 'hell', 'slavery']
# Negative Perplexity: 6957.698260650003
# Negative: ['war', 'slavery', 'killed', 'slavery', 'raping', 'raping', 'raping', 'raping', 'hell', 'raping']
# Negative Perplexity: 6954.798752916012
# Negative: ['drowned', 'hell', 'kill', 'raping', 'slavery', 'raping', 'slavery', 'killed', 'raping', 'kill']
# Negative Perplexity: 6955.198752855203
# Negative: ['wtf', 'killed', 'raping', 'hell', 'killed', 'hell', 'hell', 'hell', 'raping', 'raping']
# Negative Perplexity: 6959.597683765691
# Negative: ['bitch', 'slavery', 'raping', 'slavery', 'raping', 'raping', 'hell', 'hell', 'hell', 'killed']
# Negative Perplexity: 6957.2974992945
# Negative: ['cruel', 'kill', 'hell', 'slavery', 'slavery', 'hell', 'hell', 'slavery', 'raping', 'kill']
# Negative Perplexity: 6957.197502923491
# Negative: ['bullshit', 'hell', 'raping', 'kill', 'slavery', 'hell', 'slavery', 'raping', 'killed', 'kill']
# Negative Perplexity: 6956.498071130742
# Negative: ['ruin', 'killed', 'raping', 'kill', 'kill', 'hell', 'kill', 'hell', 'hell', 'killed']
# Negative Perplexity: 6958.597999985704
# Negative: ['hate', 'hell', 'killed', 'killed', 'killed', 'raping', 'kill', 'killed', 'hell', 'raping']
# Negative Perplexity: 6962.987767977161
# Negative: ['drown', 'killed', 'kill', 'kill', 'killed', 'hell', 'raping', 'killed', 'slavery', 'hell']
# Negative Perplexity: 6956.798810165873
# Negative: ['chaos', 'raping', 'raping', 'kill', 'killed', 'slavery', 'killed', 'raping', 'kill', 'raping']
# Negative Perplexity: 6954.8995047330545
# Negative: ['anger', 'slavery', 'kill', 'raping', 'killed', 'hell', 'hell', 'kill', 'hell', 'raping']
# Negative Perplexity: 6958.197804552654
# Negative: ['depression', 'slavery', 'slavery', 'raping', 'kill', 'raping', 'raping', 'kill', 'kill', 'hell']
# Negative Perplexity: 6954.099734727424
# Negative: ['retarded', 'killed', 'raping', 'hell', 'slavery', 'kill', 'hell', 'raping', 'killed', 'kill']
# Negative Perplexity: 6957.098140009343
# Negative: ['terrifying', 'kill', 'raping', 'killed', 'killed', 'hell', 'slavery', 'slavery', 'killed', 'hell']
# Negative Perplexity: 6956.398718205901
# Negative: ['scam', 'hell', 'raping', 'killed', 'raping', 'hell', 'killed', 'slavery', 'slavery', 'kill']
# Negative Perplexity: 6956.698030834633
# Negative: ['pathetic', 'raping', 'kill', 'raping', 'killed', 'killed', 'kill', 'raping', 'kill', 'slavery']
# Negative Perplexity: 6955.399537065538
# Negative: ['insanity', 'kill', 'hell', 'slavery', 'slavery', 'raping', 'raping', 'killed', 'kill', 'hell']
# Negative Perplexity: 6955.598775800084
# Negative: ['shit', 'kill', 'killed', 'kill', 'raping', 'raping', 'raping', 'kill', 'hell', 'kill']
# Negative Perplexity: 6958.196643063456
# Negative: ['rob', 'slavery', 'killed', 'slavery', 'slavery', 'hell', 'kill', 'hell', 'slavery', 'kill']
# Negative Perplexity: 6956.798163799845
# Negative: ['nasty', 'slavery', 'slavery', 'killed', 'raping', 'raping', 'raping', 'slavery', 'hell', 'raping']
# Negative Perplexity: 6954.998778766265
# Negative: ['died', 'raping', 'kill', 'raping', 'kill', 'killed', 'killed', 'raping', 'killed', 'hell']
# Negative Perplexity: 6956.39923525421
# Negative: ['po', 'slavery', 'raping', 'killed', 'slavery', 'killed', 'kill', 'hell', 'slavery', 'raping']
# Negative Perplexity: 6955.798709654357
# Negative: ['wars', 'raping', 'hell', 'raping', 'killed', 'raping', 'hell', 'hell', 'slavery', 'slavery']
# Negative Perplexity: 6957.497539502367
# Negative: ['crappy', 'slavery', 'raping', 'slavery', 'hell', 'kill', 'kill', 'killed', 'raping', 'raping']
# Negative Perplexity: 6955.898829674965
# Negative: ['terribly', 'slavery', 'slavery', 'raping', 'killed', 'raping', 'slavery', 'hell', 'kill', 'raping']
# Negative Perplexity: 6955.198752855203
# Negative: ['robber', 'raping', 'hell', 'raping', 'slavery', 'kill', 'slavery', 'hell', 'kill', 'raping']
# Negative Perplexity: 6956.298117174388
# Negative: ['starved', 'hell', 'raping', 'raping', 'kill', 'killed', 'slavery', 'slavery', 'kill', 'killed']
# Negative Perplexity: 6955.598775800084
# Negative: ['ban', 'kill', 'raping', 'slavery', 'raping', 'hell', 'hell', 'raping', 'hell', 'kill']
# Negative Perplexity: 6957.197502923491
# Negative: ['cheating', 'slavery', 'raping', 'slavery', 'kill', 'slavery', 'killed', 'raping', 'kill', 'killed']
# Negative Perplexity: 6954.299625492802
# Negative: ['bad', 'kill', 'kill', 'slavery', 'raping', 'killed', 'kill', 'kill', 'kill', 'raping']
# Negative Perplexity: 6961.180730753155
# Negative: ['ass', 'hell', 'killed', 'kill', 'killed', 'hell', 'raping', 'kill', 'hell', 'kill']
# Negative Perplexity: 6959.398287323235
# Negative: ['horrible', 'slavery', 'kill', 'kill', 'hell', 'killed', 'slavery', 'slavery', 'hell', 'slavery']
# Negative Perplexity: 6957.498272196027
# Negative: ['fuck', 'kill', 'slavery', 'hell', 'killed', 'raping', 'killed', 'raping', 'slavery', 'hell']
# Negative Perplexity: 6956.598617594272
# Negative: ['fail', 'killed', 'killed', 'killed', 'hell', 'kill', 'kill', 'raping', 'hell', 'slavery']
# Negative Perplexity: 6959.098513534436
# Negative: ['kills', 'raping', 'hell', 'raping', 'raping', 'hell', 'raping', 'slavery', 'raping', 'slavery']
# Negative Perplexity: 6955.498013853085
# Negative: ['suffer', 'kill', 'slavery', 'slavery', 'killed', 'raping', 'kill', 'raping', 'kill', 'kill']
# Negative Perplexity: 6954.6995967250605
# Negative: ['poison', 'killed', 'slavery', 'slavery', 'raping', 'hell', 'killed', 'kill', 'killed', 'killed']
# Negative Perplexity: 6956.398718205901
# Negative: ['bastard', 'raping', 'killed', 'hell', 'killed', 'slavery', 'raping', 'slavery', 'hell', 'killed']
# Negative Perplexity: 6956.698030834634
# Negative: ['prisoner', 'hell', 'kill', 'hell', 'killed', 'hell', 'raping', 'slavery', 'slavery', 'kill']
# Negative Perplexity: 6957.797632135215
# Negative: ['stupid', 'slavery', 'raping', 'slavery', 'raping', 'slavery', 'killed', 'slavery', 'killed', 'kill']
# Negative Perplexity: 6955.797963299977
# Negative: ['hurt', 'slavery', 'slavery', 'killed', 'hell', 'kill', 'slavery', 'hell', 'hell', 'killed']
# Negative Perplexity: 6958.697728977044
# Negative: ['sorrow', 'raping', 'kill', 'slavery', 'raping', 'slavery', 'killed', 'kill', 'hell', 'kill']
# Negative Perplexity: 6955.598775800085
# Negative: ['frustrated', 'raping', 'raping', 'raping', 'hell', 'kill', 'hell', 'killed', 'kill', 'kill']
# Negative Perplexity: 6956.898168804922
# Negative: ['punish', 'raping', 'killed', 'kill', 'slavery', 'kill', 'hell', 'raping', 'killed', 'hell']
# Negative Perplexity: 6956.298806636449
# Negative: ['casualty', 'killed', 'raping', 'hell', 'hell', 'killed', 'hell', 'kill', 'slavery', 'kill']
# Negative Perplexity: 6958.397813114202
# Negative: ['thief', 'slavery', 'hell', 'killed', 'kill', 'kill', 'slavery', 'hell', 'killed', 'slavery']
# Negative Perplexity: 6957.598330415818
# Negative: ['loser', 'raping', 'hell', 'raping', 'kill', 'raping', 'slavery', 'kill', 'killed', 'hell']
# Negative Perplexity: 6955.698806702552
# Negative: ['revenge', 'slavery', 'hell', 'hell', 'kill', 'slavery', 'hell', 'killed', 'hell', 'kill']
# Negative Perplexity: 6959.097435913968
# Negative: ['lying', 'raping', 'killed', 'kill', 'killed', 'slavery', 'slavery', 'kill', 'hell', 'kill']
# Negative Perplexity: 6956.298806636449
# Negative: ['trapped', 'kill', 'killed', 'raping', 'hell', 'killed', 'killed', 'slavery', 'slavery', 'hell']
# Negative Perplexity: 6956.398718205901
# Negative: ['sufferers', 'killed', 'slavery', 'kill', 'raping', 'kill', 'raping', 'slavery', 'kill', 'kill']
# Negative Perplexity: 6954.6995967250605
# Negative: ['terror', 'killed', 'hell', 'raping', 'hell', 'kill', 'slavery', 'slavery', 'hell', 'kill']
# Negative Perplexity: 6957.797632135215
# Negative: ['sick', 'kill', 'killed', 'raping', 'slavery', 'killed', 'killed', 'raping', 'slavery', 'slavery']
# Negative Perplexity: 6958.791702556874
# Negative: ['pain', 'killed', 'kill', 'killed', 'raping', 'hell', 'slavery', 'hell', 'slavery', 'kill']
# Negative Perplexity: 6958.29791579346
# Negative: ['failed', 'hell', 'hell', 'hell', 'killed', 'hell', 'hell', 'hell', 'slavery', 'slavery']
# Negative Perplexity: 6961.897881141412
# Negative: ['panic', 'killed', 'killed', 'killed', 'killed', 'hell', 'raping', 'killed', 'kill', 'slavery']
# Negative Perplexity: 6957.899030740786
# Negative: ['ugly', 'raping', 'slavery', 'slavery', 'slavery', 'raping', 'slavery', 'hell', 'killed', 'raping']
# Negative Perplexity: 6955.098772279131
# Negative: ['rejected', 'slavery', 'killed', 'kill', 'raping', 'killed', 'killed', 'raping', 'kill', 'slavery']
# Negative Perplexity: 6955.599465192831
# Negative: ['idiot', 'raping', 'killed', 'killed', 'hell', 'raping', 'kill', 'hell', 'hell', 'raping']
# Negative Perplexity: 6958.597942476447
# Negative: ['dumb', 'raping', 'killed', 'kill', 'killed', 'raping', 'kill', 'raping', 'slavery', 'hell']
# Negative Perplexity: 6955.099533481015
# Negative: ['depressed', 'killed', 'killed', 'kill', 'raping', 'raping', 'hell', 'kill', 'kill', 'slavery']
# Negative Perplexity: 6956.898944581677
# Negative: ['angry', 'slavery', 'slavery', 'slavery', 'raping', 'hell', 'hell', 'kill', 'kill', 'raping']
# Negative Perplexity: 6956.598201217784
# Negative: ['disappointment', 'hell', 'hell', 'slavery', 'kill', 'raping', 'hell', 'slavery', 'killed', 'killed']
# Negative Perplexity: 6957.797632135215
# Negative: ['failing', 'killed', 'raping', 'killed', 'hell', 'hell', 'raping', 'slavery', 'killed', 'slavery']
# Negative Perplexity: 6957.3981723030865
# Negative: ['failure', 'raping', 'hell', 'killed', 'kill', 'slavery', 'raping', 'raping', 'slavery', 'hell']
# Negative Perplexity: 6955.198752855203
# Negative: ['prison', 'killed', 'slavery', 'slavery', 'raping', 'kill', 'raping', 'hell', 'killed', 'kill']
# Negative Perplexity: 6955.898743432143
# Negative: ['hating', 'kill', 'killed', 'killed', 'killed', 'slavery', 'kill', 'kill', 'raping', 'raping']
# Negative Perplexity: 6955.899475957434
# Negative: ['unjust', 'killed', 'hell', 'hell', 'slavery', 'slavery', 'hell', 'raping', 'killed', 'slavery']
# Negative Perplexity: 6957.997629194085
# Negative: ['dick', 'kill', 'raping', 'killed', 'hell', 'raping', 'killed', 'hell', 'hell', 'kill']
# Negative Perplexity: 6958.397813114202
# Negative: ['scare', 'killed', 'raping', 'slavery', 'slavery', 'killed', 'slavery', 'raping', 'hell', 'raping']
# Negative Perplexity: 6955.69872045394
# Negative: ['wasted', 'kill', 'slavery', 'kill', 'kill', 'killed', 'killed', 'hell', 'raping', 'kill']
# Negative Perplexity: 6956.698892850084
# Negative: ['fear', 'slavery', 'raping', 'killed', 'kill', 'killed', 'raping', 'kill', 'kill', 'slavery']
# Negative Perplexity: 6955.399537065538
# Negative: ['screwed', 'kill', 'kill', 'hell', 'slavery', 'kill', 'hell', 'raping', 'raping', 'raping']
# Negative Perplexity: 6956.798250062089
# Negative: ['mad', 'raping', 'hell', 'hell', 'killed', 'slavery', 'raping', 'killed', 'killed', 'raping']
# Negative Perplexity: 6957.798264218444
# Negative: ['scary', 'killed', 'hell', 'hell', 'kill', 'hell', 'raping', 'kill', 'hell', 'killed']
# Negative Perplexity: 6959.797905156396
# Negative: ['infected', 'raping', 'hell', 'kill', 'slavery', 'raping', 'killed', 'slavery', 'raping', 'slavery']
# Negative Perplexity: 6955.198752855203
# Negative: ['damage', 'raping', 'hell', 'hell', 'hell', 'raping', 'kill', 'hell', 'killed', 'slavery']
# Negative Perplexity: 6959.097435913968
# Negative: ['miserable', 'raping', 'kill', 'raping', 'slavery', 'killed', 'slavery', 'slavery', 'slavery', 'raping']
# Negative Perplexity: 6953.999683730398
# Negative: ['stolen', 'hell', 'kill', 'raping', 'kill', 'killed', 'hell', 'kill', 'raping', 'raping']
# Negative Perplexity: 6957.398344834184
# Negative: ['bomb', 'raping', 'slavery', 'hell', 'raping', 'hell', 'hell', 'killed', 'slavery', 'raping']
# Negative Perplexity: 6957.597583323968
# Negative: ['enemies', 'hell', 'kill', 'raping', 'raping', 'killed', 'slavery', 'kill', 'kill', 'slavery']
# Negative Perplexity: 6955.99882175198
# Negative: ['fools', 'hell', 'raping', 'raping', 'killed', 'slavery', 'kill', 'kill', 'slavery', 'killed']
# Negative Perplexity: 6955.598775800084
# Negative: ['steal', 'killed', 'raping', 'killed', 'hell', 'slavery', 'raping', 'killed', 'slavery', 'kill']
# Negative Perplexity: 6955.998649255588
# Negative: ['shameful', 'killed', 'kill', 'slavery', 'kill', 'slavery', 'hell', 'slavery', 'raping', 'kill']
# Negative Perplexity: 6955.598775800084
# Negative: ['violate', 'kill', 'killed', 'raping', 'killed', 'killed', 'raping', 'hell', 'hell', 'hell']
# Negative Perplexity: 6957.698260650003
# Negative: ['haters', 'killed', 'raping', 'killed', 'kill', 'slavery', 'killed', 'kill', 'raping', 'slavery']
# Negative Perplexity: 6955.499435719007
# Negative: ['grief', 'killed', 'killed', 'killed', 'slavery', 'raping', 'slavery', 'killed', 'hell', 'kill']
# Negative Perplexity: 6956.598675053961
# Negative: ['sad', 'hell', 'killed', 'killed', 'slavery', 'raping', 'raping', 'kill', 'hell', 'killed']
# Negative Perplexity: 6965.061709390836
# Negative: ['wrong', 'kill', 'killed', 'raping', 'killed', 'raping', 'killed', 'hell', 'slavery', 'raping']
# Negative Perplexity: 6957.897996495442
# Negative: ['poor', 'kill', 'slavery', 'kill', 'killed', 'kill', 'hell', 'killed', 'slavery', 'killed']
# Negative Perplexity: 6492.787050346994
# Negative: ['cry', 'slavery', 'hell', 'killed', 'kill', 'killed', 'hell', 'killed', 'hell', 'hell']
# Negative Perplexity: 6960.098211779982
# Negative: ['hurts', 'raping', 'kill', 'hell', 'hell', 'slavery', 'slavery', 'slavery', 'slavery', 'slavery']
# Negative Perplexity: 6957.596894277553
# Negative: ['badly', 'slavery', 'slavery', 'hell', 'killed', 'raping', 'hell', 'raping', 'raping', 'killed']
# Negative Perplexity: 6956.498071130742
# Negative: ['terrible', 'slavery', 'killed', 'hell', 'kill', 'kill', 'raping', 'slavery', 'killed', 'hell']
# Negative Perplexity: 6956.598847565233
# Negative: ['disappointed', 'killed', 'hell', 'slavery', 'raping', 'kill', 'kill', 'hell', 'killed', 'hell']
# Negative Perplexity: 6958.098427352167
# Negative: ['worse', 'raping', 'killed', 'kill', 'hell', 'kill', 'hell', 'hell', 'slavery', 'slavery']
# Negative Perplexity: 6958.9979883854085
# Negative: ['gross', 'raping', 'raping', 'raping', 'raping', 'slavery', 'kill', 'hell', 'killed', 'killed']
# Negative Perplexity: 6955.598775800084
# Negative: ['shame', 'killed', 'killed', 'killed', 'slavery', 'kill', 'killed', 'hell', 'slavery', 'raping']
# Negative Perplexity: 6957.098829550697
# Negative: ['crying', 'kill', 'raping', 'slavery', 'kill', 'killed', 'killed', 'killed', 'killed', 'slavery']
# Negative Perplexity: 6956.899360976166
# Negative: ['broken', 'hell', 'kill', 'killed', 'kill', 'killed', 'kill', 'hell', 'raping', 'kill']
# Negative Perplexity: 6958.398617807857
# Negative: ['fake', 'hell', 'raping', 'hell', 'raping', 'kill', 'raping', 'raping', 'hell', 'kill']
# Negative Perplexity: 6957.397597763808
# Negative: ['attack', 'hell', 'kill', 'hell', 'hell', 'raping', 'kill', 'raping', 'slavery', 'kill']
# Negative Perplexity: 6957.797747173576
# Negative: ['shattered', 'kill', 'raping', 'killed', 'hell', 'raping', 'slavery', 'hell', 'raping', 'kill']
# Negative Perplexity: 6956.598114966291
# Negative: ['ruined', 'slavery', 'kill', 'hell', 'hell', 'hell', 'hell', 'raping', 'killed', 'killed']
# Negative Perplexity: 6959.297585397952
# Negative: ['ashamed', 'raping', 'raping', 'raping', 'slavery', 'killed', 'hell', 'hell', 'killed', 'killed']
# Negative Perplexity: 6956.698030834633
# Negative: ['accident', 'slavery', 'slavery', 'slavery', 'slavery', 'raping', 'kill', 'killed', 'raping', 'kill']
# Negative Perplexity: 6953.999683730398
# Negative: ['choked', 'raping', 'kill', 'killed', 'slavery', 'kill', 'slavery', 'raping', 'slavery', 'hell']
# Negative Perplexity: 6954.299625492802
# Negative: ['oppressed', 'killed', 'kill', 'raping', 'kill', 'raping', 'kill', 'hell', 'slavery', 'raping']
# Negative Perplexity: 6955.99882175198
# Negative: ['unpleasant', 'slavery', 'hell', 'kill', 'kill', 'slavery', 'kill', 'hell', 'killed', 'raping']
# Negative Perplexity: 6957.298289490414
# Negative: ['rude', 'hell', 'slavery', 'raping', 'slavery', 'killed', 'hell', 'raping', 'slavery', 'raping']
# Negative Perplexity: 6956.298059684139
# Negative: ['jealous', 'kill', 'raping', 'raping', 'hell', 'hell', 'kill', 'killed', 'raping', 'slavery']
# Negative Perplexity: 6957.9980027450165
# Negative: ['appalled', 'slavery', 'kill', 'raping', 'killed', 'slavery', 'slavery', 'kill', 'kill', 'killed']
# Negative Perplexity: 6954.6995967250605
# Negative: ['irritated', 'slavery', 'hell', 'slavery', 'kill', 'raping', 'raping', 'slavery', 'killed', 'killed']
# Negative Perplexity: 6955.298778004801
# Negative: ['frustrations', 'raping', 'kill', 'killed', 'kill', 'hell', 'raping', 'raping', 'hell', 'killed']
# Negative Perplexity: 6956.898168804922
# Negative: ['unfortunate', 'slavery', 'raping', 'raping', 'slavery', 'raping', 'kill', 'raping', 'killed', 'kill']
# Negative Perplexity: 6953.999683730398
# Negative: ['threatened', 'slavery', 'killed', 'raping', 'hell', 'kill', 'killed', 'raping', 'hell', 'raping']
# Negative Perplexity: 6957.098140009343
# Negative: ['forced', 'hell', 'slavery', 'slavery', 'raping', 'hell', 'raping', 'slavery', 'raping', 'killed']
# Negative Perplexity: 6955.498013853085
# Negative: ['attacking', 'killed', 'hell', 'raping', 'slavery', 'slavery', 'raping', 'raping', 'hell', 'raping']
# Negative Perplexity: 6956.09799646655
# Negative: ['sucked', 'killed', 'hell', 'kill', 'slavery', 'kill', 'raping', 'hell', 'killed', 'hell']
# Negative Perplexity: 6957.7984080122715
# Negative: ['troubles', 'killed', 'killed', 'killed', 'kill', 'kill', 'raping', 'killed', 'hell', 'killed']
# Negative Perplexity: 6957.599005619092
# Negative: ['irritating', 'slavery', 'kill', 'killed', 'kill', 'raping', 'hell', 'killed', 'raping', 'killed']
# Negative Perplexity: 6956.198767105296
# Negative: ['attacked', 'hell', 'slavery', 'killed', 'kill', 'killed', 'raping', 'kill', 'killed', 'raping']
# Negative Perplexity: 6956.898858326456
# Negative: ['awful', 'slavery', 'raping', 'hell', 'raping', 'slavery', 'raping', 'slavery', 'killed', 'raping']
# Negative Perplexity: 6955.098772279131
# Negative: ['heartbreaking', 'slavery', 'kill', 'kill', 'killed', 'killed', 'killed', 'raping', 'raping', 'kill']
# Negative Perplexity: 6955.499435719008
# Negative: ['beating', 'kill', 'hell', 'killed', 'hell', 'kill', 'slavery', 'raping', 'hell', 'raping']
# Negative Perplexity: 6958.197804552654
# Negative: ['banned', 'raping', 'raping', 'raping', 'kill', 'killed', 'killed', 'slavery', 'kill', 'hell']
# Negative Perplexity: 6954.999525579061
# Negative: ['cheat', 'slavery', 'killed', 'killed', 'slavery', 'kill', 'killed', 'slavery', 'kill', 'hell']
# Negative Perplexity: 6955.499435719008
# Negative: ['dire', 'slavery', 'killed', 'hell', 'killed', 'killed', 'kill', 'hell', 'hell', 'hell']
# Negative Perplexity: 6958.998045864917
# Negative: ['scared', 'raping', 'kill', 'killed', 'killed', 'slavery', 'raping', 'killed', 'hell', 'hell']
# Negative Perplexity: 6957.19869514603
# Negative: ['tired', 'raping', 'hell', 'hell', 'hell', 'raping', 'raping', 'killed', 'hell', 'raping']
# Negative Perplexity: 6962.690163190171
# Negative: ['block', 'kill', 'killed', 'hell', 'kill', 'hell', 'hell', 'killed', 'hell', 'kill']
# Negative Perplexity: 6960.498315436298
# Negative: ['bloody', 'slavery', 'kill', 'killed', 'kill', 'slavery', 'killed', 'killed', 'hell', 'hell']
# Negative Perplexity: 6956.998893539452
# Negative: ['weak', 'hell', 'hell', 'slavery', 'raping', 'raping', 'killed', 'slavery', 'raping', 'slavery']
# Negative Perplexity: 6956.09799646655
# Negative: ['attacks', 'hell', 'kill', 'killed', 'killed', 'slavery', 'slavery', 'kill', 'kill', 'raping']
# Negative Perplexity: 6956.598847565233
# Negative: ['sadness', 'raping', 'slavery', 'hell', 'kill', 'raping', 'raping', 'kill', 'slavery', 'kill']
# Negative Perplexity: 6955.398847692606
# Negative: ['freak', 'hell', 'kill', 'hell', 'kill', 'hell', 'hell', 'raping', 'hell', 'raping']
# Negative Perplexity: 6960.29751351048
# Negative: ['hates', 'killed', 'raping', 'slavery', 'raping', 'raping', 'kill', 'hell', 'slavery', 'killed']
# Negative Perplexity: 6955.598775800085
# Negative: ['annoy', 'slavery', 'hell', 'kill', 'kill', 'hell', 'raping', 'hell', 'slavery', 'killed']
# Negative Perplexity: 6957.697700473803
# Negative: ['worry', 'kill', 'slavery', 'slavery', 'kill', 'hell', 'killed', 'slavery', 'hell', 'kill']
# Negative Perplexity: 6957.298289490414
# Negative: ['ruins', 'slavery', 'hell', 'slavery', 'kill', 'raping', 'raping', 'killed', 'raping', 'raping']
# Negative Perplexity: 6955.198752855203
# Negative: ['mourning', 'slavery', 'hell', 'hell', 'raping', 'kill', 'raping', 'killed', 'killed', 'hell']
# Negative Perplexity: 6957.098140009343
# Negative: ['painful', 'slavery', 'raping', 'slavery', 'hell', 'raping', 'hell', 'hell', 'raping', 'killed']
# Negative Perplexity: 6956.797388034328
# Negative: ['dirty', 'hell', 'raping', 'slavery', 'killed', 'killed', 'hell', 'killed', 'kill', 'killed']
# Negative Perplexity: 6957.698260650003
# Negative: ['meaningless', 'hell', 'raping', 'raping', 'kill', 'killed', 'kill', 'killed', 'slavery', 'hell']
# Negative Perplexity: 6956.198767105296
# Negative: ['suck', 'kill', 'raping', 'kill', 'hell', 'hell', 'kill', 'hell', 'killed', 'hell']
# Negative Perplexity: 6959.598157971454
# Negative: ['abandon', 'kill', 'slavery', 'slavery', 'killed', 'slavery', 'slavery', 'kill', 'slavery', 'raping']
# Negative Perplexity: 6954.299625492802
# Negative: ['undesirable', 'kill', 'slavery', 'raping', 'raping', 'killed', 'raping', 'slavery', 'kill', 'hell']
# Negative Perplexity: 6954.299625492802
# Negative: ['woes', 'kill', 'killed', 'raping', 'slavery', 'hell', 'kill', 'raping', 'killed', 'raping']
# Negative Perplexity: 6956.198767105296
# Negative: ['ill', 'slavery', 'killed', 'slavery', 'hell', 'killed', 'raping', 'kill', 'raping', 'slavery']
# Negative Perplexity: 6964.55251052139
# Negative: ['sadly', 'kill', 'raping', 'hell', 'hell', 'hell', 'killed', 'killed', 'slavery', 'raping']
# Negative Perplexity: 6958.898039425965
# Negative: ['starving', 'raping', 'slavery', 'killed', 'kill', 'raping', 'slavery', 'raping', 'kill', 'raping']
# Negative Perplexity: 6954.399637711735
# Negative: ['broke', 'kill', 'hell', 'raping', 'kill', 'slavery', 'raping', 'slavery', 'raping', 'raping']
# Negative Perplexity: 6956.198249997653
# Negative: ['threats', 'kill', 'kill', 'killed', 'killed', 'kill', 'slavery', 'kill', 'hell', 'kill']
# Negative Perplexity: 6957.099002074371
# Negative: ['stress', 'raping', 'killed', 'kill', 'raping', 'raping', 'raping', 'hell', 'hell', 'killed']
# Negative Perplexity: 6956.798163799845
# Negative: ['lame', 'kill', 'kill', 'hell', 'slavery', 'slavery', 'hell', 'hell', 'slavery', 'slavery']
# Negative Perplexity: 6958.197804552654
# Negative: ['fakes', 'slavery', 'raping', 'slavery', 'killed', 'kill', 'slavery', 'raping', 'kill', 'kill']
# Negative Perplexity: 6954.299625492802
# Negative: ['disheartening', 'slavery', 'kill', 'raping', 'raping', 'hell', 'killed', 'slavery', 'raping', 'slavery']
# Negative Perplexity: 6955.198752855203
# Negative: ['weakness', 'slavery', 'hell', 'killed', 'killed', 'hell', 'killed', 'kill', 'kill', 'killed']
# Negative Perplexity: 6958.098427352167
# Negative: ['unhappy', 'raping', 'slavery', 'killed', 'hell', 'raping', 'slavery', 'raping', 'raping', 'hell']
# Negative Perplexity: 6954.798752916012
# Negative: ['guilty', 'raping', 'raping', 'killed', 'killed', 'slavery', 'kill', 'slavery', 'slavery', 'hell']
# Negative Perplexity: 6954.499522003902
# Negative: ['useless', 'slavery', 'killed', 'killed', 'kill', 'killed', 'hell', 'slavery', 'killed', 'slavery']
# Negative Perplexity: 6956.998778514299
# Negative: ['worries', 'hell', 'slavery', 'raping', 'slavery', 'kill', 'killed', 'killed', 'killed', 'hell']
# Negative Perplexity: 6956.498760612621
# Negative: ['beaten', 'killed', 'slavery', 'hell', 'killed', 'killed', 'raping', 'raping', 'killed', 'hell']
# Negative Perplexity: 6956.6987203363315
# Negative: ['vain', 'slavery', 'raping', 'slavery', 'killed', 'slavery', 'hell', 'kill', 'hell', 'kill']
# Negative Perplexity: 6956.498071130742
# Negative: ['injury', 'hell', 'hell', 'hell', 'slavery', 'killed', 'kill', 'killed', 'hell', 'hell']
# Negative Perplexity: 6959.697729014282
# Negative: ['waste', 'killed', 'kill', 'killed', 'kill', 'slavery', 'slavery', 'killed', 'raping', 'killed']
# Negative Perplexity: 6955.599465192831
# Negative: ['fails', 'killed', 'killed', 'hell', 'killed', 'slavery', 'slavery', 'slavery', 'kill', 'hell']
# Negative Perplexity: 6956.398718205901
# Negative: ['lies', 'kill', 'raping', 'hell', 'kill', 'kill', 'kill', 'raping', 'slavery', 'raping']
# Negative Perplexity: 6955.79888214579
# Negative: ['crash', 'kill', 'raping', 'kill', 'kill', 'kill', 'slavery', 'raping', 'raping', 'hell']
# Negative Perplexity: 6954.89967720219
# Negative: ['problem', 'kill', 'hell', 'slavery', 'killed', 'killed', 'slavery', 'kill', 'killed', 'slavery']
# Negative Perplexity: 6957.398904986283
# Negative: ['problems', 'hell', 'slavery', 'killed', 'hell', 'hell', 'killed', 'killed', 'raping', 'slavery']
# Negative Perplexity: 6958.697901457737
# Negative: ['blind', 'hell', 'slavery', 'raping', 'killed', 'kill', 'kill', 'killed', 'raping', 'slavery']
# Negative Perplexity: 6956.298806636449
# Negative: ['annoying', 'raping', 'kill', 'raping', 'slavery', 'slavery', 'kill', 'slavery', 'kill', 'hell']
# Negative Perplexity: 6954.899447287399
# Negative: ['damn', 'kill', 'hell', 'hell', 'killed', 'killed', 'kill', 'raping', 'killed', 'kill']
# Negative Perplexity: 6960.79569719412
# Negative: ['dull', 'hell', 'raping', 'slavery', 'killed', 'kill', 'raping', 'kill', 'kill', 'hell']
# Negative Perplexity: 6956.19888211722
# Negative: ['insane', 'killed', 'killed', 'kill', 'kill', 'raping', 'hell', 'raping', 'kill', 'raping']
# Negative Perplexity: 6956.998951035493
# Negative: ['fault', 'slavery', 'kill', 'kill', 'kill', 'hell', 'raping', 'killed', 'killed', 'hell']
# Negative Perplexity: 6956.898944581678
# Negative: ['trouble', 'killed', 'kill', 'hell', 'raping', 'raping', 'hell', 'killed', 'raping', 'killed']
# Negative Perplexity: 6957.298231991899
# Negative: ['error', 'kill', 'raping', 'slavery', 'killed', 'killed', 'slavery', 'killed', 'slavery', 'slavery']
# Negative Perplexity: 6955.099418487266
# Negative: ['stink', 'slavery', 'raping', 'slavery', 'raping', 'slavery', 'raping', 'kill', 'kill', 'slavery']
# Negative Perplexity: 6953.79980158639
# Negative: ['dumped', 'slavery', 'hell', 'killed', 'killed', 'killed', 'hell', 'slavery', 'killed', 'hell']
# Negative Perplexity: 6957.898254852509
# Negative: ['lose', 'killed', 'raping', 'hell', 'hell', 'hell', 'kill', 'hell', 'kill', 'killed']
# Negative Perplexity: 6959.697844084058
# Negative: ['complaints', 'slavery', 'hell', 'raping', 'hell', 'raping', 'raping', 'raping', 'raping', 'slavery']
# Negative Perplexity: 6955.498013853085
# Negative: ['hurting', 'hell', 'killed', 'kill', 'slavery', 'killed', 'hell', 'raping', 'slavery', 'hell']
# Negative Perplexity: 6957.098140009343
# Negative: ['injured', 'slavery', 'raping', 'raping', 'kill', 'kill', 'hell', 'killed', 'raping', 'killed']
# Negative Perplexity: 6955.698806702552
# Negative: ['hacked', 'hell', 'slavery', 'slavery', 'killed', 'kill', 'killed', 'kill', 'hell', 'raping']
# Negative Perplexity: 6957.598330415818
# Negative: ['shocking', 'raping', 'killed', 'raping', 'slavery', 'hell', 'raping', 'killed', 'killed', 'kill']
# Negative Perplexity: 6955.998649255588
# Negative: ['fights', 'hell', 'raping', 'slavery', 'slavery', 'raping', 'kill', 'kill', 'killed', 'hell']
# Negative Perplexity: 6955.698806702552
# Negative: ['traumatized', 'hell', 'hell', 'killed', 'slavery', 'killed', 'raping', 'raping', 'slavery', 'kill']
# Negative Perplexity: 6956.698030834634
# Negative: ['cries', 'hell', 'slavery', 'slavery', 'hell', 'slavery', 'slavery', 'slavery', 'hell', 'raping']
# Negative Perplexity: 6956.797388034328
# Negative: ['scream', 'hell', 'hell', 'kill', 'kill', 'hell', 'kill', 'hell', 'slavery', 'slavery']
# Negative Perplexity: 6959.297642912991
# Negative: ['upset', 'raping', 'hell', 'killed', 'killed', 'raping', 'killed', 'hell', 'hell', 'killed']
# Negative Perplexity: 6958.998045864917
# Negative: ['crap', 'raping', 'slavery', 'slavery', 'raping', 'raping', 'slavery', 'kill', 'raping', 'killed']
# Negative Perplexity: 6954.199399250683
# Negative: ['cried', 'raping', 'kill', 'raping', 'hell', 'slavery', 'raping', 'hell', 'hell', 'killed']
# Negative Perplexity: 6957.4976257650105
# Negative: ['flu', 'raping', 'slavery', 'hell', 'slavery', 'kill', 'slavery', 'killed', 'killed', 'kill']
# Negative Perplexity: 6956.198767105296
# Negative: ['battlefield', 'slavery', 'hell', 'kill', 'raping', 'kill', 'kill', 'hell', 'killed', 'kill']
# Negative Perplexity: 6957.298289490414
# Negative: ['losing', 'raping', 'raping', 'kill', 'kill', 'kill', 'hell', 'slavery', 'slavery', 'killed']
# Negative Perplexity: 6955.898858414308
# Negative: ['fight', 'killed', 'hell', 'hell', 'hell', 'slavery', 'killed', 'hell', 'raping', 'slavery']
# Negative Perplexity: 6959.497625571937
# Negative: ['screaming', 'kill', 'kill', 'raping', 'raping', 'slavery', 'kill', 'kill', 'hell', 'hell']
# Negative Perplexity: 6955.79888214579
# Negative: ['battle', 'slavery', 'slavery', 'slavery', 'slavery', 'killed', 'kill', 'slavery', 'hell', 'kill']
# Negative Perplexity: 6955.39879020979
# Negative: ['severe', 'slavery', 'raping', 'hell', 'kill', 'hell', 'slavery', 'kill', 'hell', 'raping']
# Negative Perplexity: 6957.697700473803
# Negative: ['battles', 'raping', 'killed', 'hell', 'hell', 'slavery', 'kill', 'slavery', 'kill', 'hell']
# Negative Perplexity: 6956.898168804922
# Negative: ['disturbed', 'kill', 'killed', 'hell', 'killed', 'killed', 'raping', 'raping', 'raping', 'slavery']
# Negative Perplexity: 6956.398718205901
# Negative: ['lied', 'killed', 'raping', 'killed', 'hell', 'raping', 'hell', 'killed', 'killed', 'kill']
# Negative Perplexity: 6957.898254852508
# Negative: ['grieve', 'slavery', 'killed', 'raping', 'killed', 'killed', 'kill', 'hell', 'raping', 'slavery']
# Negative Perplexity: 6956.398718205901
# Negative: ['annoyed', 'slavery', 'kill', 'killed', 'kill', 'raping', 'raping', 'kill', 'raping', 'hell']
# Negative Perplexity: 6954.899619723498
# Negative: ['blocking', 'raping', 'killed', 'hell', 'raping', 'raping', 'hell', 'raping', 'raping', 'slavery']
# Negative Perplexity: 6956.09799646655
# Negative: ['embarrassing', 'killed', 'killed', 'kill', 'raping', 'raping', 'hell', 'slavery', 'hell', 'kill']
# Negative Perplexity: 6957.098140009343
# Negative: ['smuggle', 'killed', 'kill', 'slavery', 'slavery', 'raping', 'killed', 'killed', 'hell', 'slavery']
# Negative Perplexity: 6956.398718205901
# Negative: ['dump', 'slavery', 'raping', 'slavery', 'kill', 'raping', 'killed', 'raping', 'raping', 'raping']
# Negative Perplexity: 6953.899677263261
# Negative: ['grave', 'killed', 'killed', 'raping', 'slavery', 'slavery', 'hell', 'raping', 'kill', 'slavery']
# Negative Perplexity: 6955.798709654357
# Negative: ['funerals', 'slavery', 'kill', 'killed', 'kill', 'killed', 'raping', 'slavery', 'killed', 'slavery']
# Negative Perplexity: 6955.499435719008
# Negative: ['shock', 'killed', 'hell', 'raping', 'hell', 'hell', 'hell', 'killed', 'kill', 'hell']
# Negative Perplexity: 6959.697729014282
# Negative: ['inconvenience', 'hell', 'hell', 'killed', 'hell', 'killed', 'kill', 'raping', 'killed', 'kill']
# Negative Perplexity: 6958.998045864917
# Negative: ['sore', 'hell', 'hell', 'hell', 'hell', 'slavery', 'killed', 'raping', 'hell', 'kill']
# Negative Perplexity: 6960.79757434843
# Negative: ['ridiculous', 'slavery', 'raping', 'slavery', 'killed', 'raping', 'slavery', 'hell', 'raping', 'slavery']
# Negative Perplexity: 6954.89877231307
# Negative: ['sucks', 'killed', 'slavery', 'killed', 'slavery', 'raping', 'killed', 'raping', 'raping', 'hell']
# Negative Perplexity: 6956.8968350139985
# Negative: ['spam', 'hell', 'hell', 'raping', 'killed', 'kill', 'killed', 'slavery', 'hell', 'killed']
# Negative Perplexity: 6958.597942476448
# Negative: ['doubt', 'kill', 'raping', 'hell', 'kill', 'hell', 'killed', 'slavery', 'slavery', 'hell']
# Negative Perplexity: 6957.298289490414
# Negative: ['exhausted', 'killed', 'hell', 'kill', 'kill', 'kill', 'kill', 'slavery', 'raping', 'kill']
# Negative Perplexity: 6956.898973325153
# Negative: ['regrets', 'hell', 'kill', 'hell', 'kill', 'kill', 'raping', 'raping', 'hell', 'killed']
# Negative Perplexity: 6958.197919597631
# Negative: ['lazy', 'slavery', 'raping', 'kill', 'raping', 'slavery', 'kill', 'killed', 'slavery', 'kill']
# Negative Perplexity: 6954.8995047330545
# Negative: ['fighting', 'killed', 'hell', 'slavery', 'kill', 'killed', 'killed', 'killed', 'killed', 'killed']
# Negative Perplexity: 6957.698950250837
# Negative: ['mischief', 'kill', 'kill', 'kill', 'slavery', 'kill', 'hell', 'killed', 'killed', 'kill']
# Negative Perplexity: 6956.998951035493
# Negative: ['lonely', 'kill', 'kill', 'slavery', 'raping', 'slavery', 'raping', 'killed', 'hell', 'kill']
# Negative Perplexity: 6956.098800894247

# %%
ls_neg_gen = []
lm = LanguageModel(laplace_smoothed_bigrams, unigram_probs, "vader", True, False, True, repetition_penalty=0.2)
for p in neg_prompts:
    sentence_neg = lm.generate_text([p], sentiment=-1, length=10)
    print(sentence_neg)
    print("Negative: {}".format(sentence_neg))
    ppl = lm.computePerplexity(sentence_neg)
    print("Negative Perplexity: {}".format(ppl))
    ls_neg_gen.append((sentence_neg, ppl))
    append_to_file('neg_gen_mul_numerator.txt', " ".join(sentence_neg), str(ppl))
# Out:
# ['raping', 'slavery', 'and', 'a', 'great', 'time', 'to', 'the', 'best', 'i']
# Negative: ['raping', 'slavery', 'and', 'a', 'great', 'time', 'to', 'the', 'best', 'i']
# Negative Perplexity: 901.6885266295739
# ['slavery', 'killed', 'tea', 'so', 'i', 'dont', 'want', 'to', 'the', 'last']
# Negative: ['slavery', 'killed', 'tea', 'so', 'i', 'dont', 'want', 'to', 'the', 'last']
# Negative Perplexity: 719.3617643744873
# ['kill', 'me', 'too', 'early', 'today', 'i', 'was', 'just', 'woke', 'up']
# Negative: ['kill', 'me', 'too', 'early', 'today', 'i', 'was', 'just', 'woke', 'up']
# Negative Perplexity: 761.6359982131581
# ['hell', 'everybody', 'day', 'to', 'the', 'same', 'page', 'of', 'my', 'phone']
# Negative: ['hell', 'everybody', 'day', 'to', 'the', 'same', 'page', 'of', 'my', 'phone']
# Negative Perplexity: 1041.171891177359
# ['killed', 'a', 'good', 'day', 'with', 'you', 'can', 'get', 'my', 'mom']
# Negative: ['killed', 'a', 'good', 'day', 'with', 'you', 'can', 'get', 'my', 'mom']
# Negative Perplexity: 814.5223455065095
# ['killing', 'me', 'to', 'go', 'to', 'work', 'on', 'twitter', 'but', 'i']
# Negative: ['killing', 'me', 'to', 'go', 'to', 'work', 'on', 'twitter', 'but', 'i']
# Negative Perplexity: 493.75902320763475
# ['evil', 'me', 'too', 'i', 'am', 'and', 'i', 'cant', 'find', 'you']
# Negative: ['evil', 'me', 'too', 'i', 'am', 'and', 'i', 'cant', 'find', 'you']
# Negative Perplexity: 670.6594703701854

# %%
ls_neg_gen = []
lm = LanguageModel(laplace_smoothed_bigrams, unigram_probs, "vader", True, False, True, repetition_penalty=0.2)
for p in neg_prompts:
    sentence_neg = lm.generate_text([p], sentiment=-1, length=10)
    print(sentence_neg)
    print("Negative: {}".format(sentence_neg))
    ppl = lm.computePerplexity(sentence_neg)
    print("Negative Perplexity: {}".format(ppl))
    ls_neg_gen.append((sentence_neg, ppl))
    append_to_file('neg_gen_div_denominator.txt', " ".join(sentence_neg), str(ppl))
