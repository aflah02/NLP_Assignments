# %%
import pandas as pd
import numpy as np
import pickle
from preprocess_text import *
from bigrams import *
from smoothers import *
from LanguageModels import *

# %%
df = pd.read_csv('A1_dataset.csv')

# %%
# text = df['TEXT'].to_list()
# def preprocess_text(text):
#     text = lowercase_text(text)
#     text = remove_url_html(text)
#     text = remove_users(text)
#     text = remove_punctuations(text)
#     text = remove_whitespaces(text)
#     text = tokenization(text)
#     text = spelling_correction(text, 'autocorrect_full')
#     text = remove_alphanum(text)
#     return text
# df['preprocessed_text'] = df['TEXT'].progress_apply(preprocess_text)
# preprocess_text = df['preprocessed_text'].to_list()
# df.to_csv('preprocessed_A1.csv', index=False)

# %%
df = pd.read_csv('preprocessed_A1.csv')
preprocess_text = df['preprocessed_text'].to_list()
for i in range(len(preprocess_text)):
    preprocess_text[i] = eval(preprocess_text[i])

# %%
unigram_counts = {}
for sentence in preprocess_text:
    for word in sentence:
        if word in unigram_counts:
            unigram_counts[word] += 1
        else:
            unigram_counts[word] = 1

# %%
unigram_probs = {}
scale_factor = sum(unigram_counts.values())
for word in unigram_counts:
    unigram_probs[word] = unigram_counts[word] / scale_factor

# %%
len(unigram_counts)
# Out:
# 6952

# %% [markdown]
# # Saving Bigrams with Smoothing

# %%
# bigram_wrapper = Bigrams(preprocess_text)
# bigrams = bigram_wrapper.get_bigrams()
# vocab_len = bigram_wrapper.vocab_len

# with open('bigram_model_dumps/bigram_wrapper.pickle', 'wb') as f:
#     pickle.dump(bigram_wrapper, f)

# %%
# load bigram_wrapper
# with open('bigram_wrapper.pickle', 'rb') as f:
#     bigram_wrapper = pickle.load(f)

# bigrams = bigram_wrapper.get_bigrams()
# vocab_len = bigram_wrapper.vocab_len

# %%
# smoother = LMSmoothers(bigrams, vocab_len, unigram_counts=unigram_counts, unigrams_probs=unigram_probs)
# laplace_smoothed_bigrams = smoother.laplace()
# add_5_smoothed_bigrams = smoother.add_k(5)
# add_5_with_unigram_prior_smoothed_bigrams = smoother.add_k_with_unigram_prior(5)

# %%
# with open('bigram_model_dumps/laplace_smoothed_bigrams.pickle', 'wb') as handle:
#     pickle.dump(laplace_smoothed_bigrams, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('bigram_model_dumps/add_5_smoothed_bigrams.pickle', 'wb') as handle:
#     pickle.dump(add_5_smoothed_bigrams, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('bigram_model_dumps/add_5_with_unigram_prior_smoothed_bigrams.pickle', 'wb') as handle:
#     pickle.dump(add_5_with_unigram_prior_smoothed_bigrams, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Creating BiGram Models

# %%
with open('bigram_model_dumps/laplace_smoothed_bigrams.pickle', 'rb') as handle:
    laplace_smoothed_bigrams = pickle.load(handle)

# with open('bigram_model_dumps/add_5_smoothed_bigrams.pickle', 'rb') as handle:
#     add_5_smoothed_bigrams = pickle.load(handle)

# with open('bigram_model_dumps/add_5_with_unigram_prior_smoothed_bigrams.pickle', 'rb') as handle:
#     add_5_with_unigram_prior_smoothed_bigrams = pickle.load(handle)

# %%
# Load Negative Prompts
with open('Pos Neg Prompts/neg_250_hf.txt', 'rb') as handle:
    neg_prompts = handle.readlines()

for i in range(len(neg_prompts)):
    neg_prompts[i] = neg_prompts[i].decode('utf-8').strip()

# %%
# clear the file
open('neg_hf_prompts.txt', 'w').close()

# %%
def append_to_file(filename, text1, text2):
    with open(filename, 'a') as f:
        f.write(text1 + " " + text2 + '\n')

# %%
ls_neg_gen = []
lm = LanguageModel(laplace_smoothed_bigrams, unigram_probs, "vader", False, False, True, repetition_penalty=0.2, normalizebyPerplexity=True, sentiment_scale_factor=1)
for p in neg_prompts:
    sentence_neg = lm.generate_text([p], sentiment=-1, length=10)
    print("Negative: {}".format(sentence_neg))
    ppl = lm.computePerplexity(sentence_neg)
    print("Negative Perplexity: {}".format(ppl))
    ls_neg_gen.append((sentence_neg, ppl))
    append_to_file('neg_hf_prompts.txt', " ".join(sentence_neg), str(ppl))
# Out:
# Negative: ['pathetic', 'hell', 'everybody', 'see', 'you', 'raping', 'kill', 'myself', 'in', 'killed']
# Negative Perplexity: 3703.6524377097257
# Negative: ['lagging', 'hell', 'get', 'slavery', 'killed', 'the', 'worst', 'part', 'of', 'my']
# Negative Perplexity: 2689.8469168530464
# Negative: ['irritating', 'slavery', 'killed', 'the', 'shittiest', 'hell', 'killing', 'me', 'raping', 'horrific']
# Negative Perplexity: 4837.780965025023
# Negative: ['messes', 'slavery', 'hell', 'my', 'killed', 'tea', 'so', 'bad', 'raping', 'evil']
# Negative Perplexity: 4447.7552576720245
# Negative: ['appalling', 'kill', 'me', 'sad', 'killed', 'a', 'bad', 'hell', 'yeah', 'raping']
# Negative Perplexity: 3666.5612733438256
# Negative: ['worst', 'dreams', 'and', 'crisis', 'kill', 'slavery', 'raping', 'killing', 'mee', 'tragedy']
# Negative Perplexity: 5116.034543991969
# Negative: ['garbage', 'slavery', 'kill', 'raping', 'tragedy', 'arms', 'for', 'the', 'hell', 'yeah']
# Negative Perplexity: 3007.7760066118663
# Negative: ['useless', 'bloatware', 'kill', 'chris', 'raping', 'slavery', 'hell', 'killed', 'im', 'tragedy']
# Negative Perplexity: 5686.1644561352105
# Negative: ['rubbish', 'slavery', 'kill', 'hell', 'my', 'killed', 'the', 'raping', 'evil', 'tragedy']
# Negative Perplexity: 5818.35409746496
# Negative: ['worse', 'study', 'and', 'i', 'have', 'a', 'kill', 'me', 'sad', 'raping']
# Negative Perplexity: 1219.6558347201842
# Negative: ['mess', 'of', 'the', 'shit', 'alone', 'raping', 'hell', 'yeah', 'tragedy', 'arms']
# Negative Perplexity: 3035.6694071044876
# Negative: ['sink', 'raping', 'kill', 'me', 'sad', 'slavery', 'killing', 'me', 'killed', 'a']
# Negative Perplexity: 4115.567854217133
# Negative: ['bored', 'of', 'pain', 'work', 'hell', 'slavery', 'kill', 'killed', 'the', 'dead']
# Negative Perplexity: 3944.0173198706216
# Negative: ['floppies', 'raping', 'slavery', 'kill', 'myself', 'in', 'the', 'dead', 'tired', 'of']
# Negative Perplexity: 2444.2255692242443
# Negative: ['annoying', 'that', 'was', 'a', 'bitch', 'haha', 'hell', 'kill', 'myself', 'slavery']
# Negative Perplexity: 2834.484479938141
# Negative: ['awful', 'haha', 'i', 'failed', 'at', 'raping', 'killed', 'im', 'dead', 'hell']
# Negative Perplexity: 3435.6747655289214
# Negative: ['ugly', 'useless', 'bloatware', 'slavery', 'hell', 'is', 'dead', 'kill', 'me', 'raping']
# Negative Perplexity: 4792.015401362021
# Negative: ['disappointment', 'slavery', 'hell', 'get', 'it', 'killed', 'a', 'bitch', 'loljkmines', 'almost']
# Negative Perplexity: 3616.306488978905
# Negative: ['waste', 'as', 'bad', 'raping', 'nick', 'to', 'kill', 'me', 'killing', 'me']
# Negative Perplexity: 3532.924001921782
# Negative: ['dim', 'kill', 'chris', 'wants', 'to', 'worst', 'slavery', 'and', 'i', 'hell']
# Negative Perplexity: 2797.6971046221806
# Negative: ['meaningless', 'tweets', 'kill', 'raping', 'nick', 'he', 'is', 'sad', 'killing', 'it']
# Negative Perplexity: 3522.2259197219614
# Negative: ['poor', 'hell', 'yeah', 'i', 'slavery', 'killed', 'the', 'dead', 'horrific', 'ended']
# Negative Perplexity: 3471.305295673256
# Negative: ['junk', 'food', 'battles', 'kill', 'me', 'sad', 'raping', 'slavery', 'and', 'crisis']
# Negative Perplexity: 4018.856985203347
# Negative: ['poorly', 'belly', 'acres', 'hell', 'get', 'a', 'bad', 'killed', 'a', 'horrific']
# Negative Perplexity: 3303.1171858096654
# Negative: ['miserable', 'kill', 'slavery', 'killed', 'the', 'hell', 'evil', 'killing', 'me', 'tragedy']
# Negative Perplexity: 4414.6463033815735
# Negative: ['lame', 'but', 'i', 'hate', 'slavery', 'kill', 'me', 'cry', 'legs', 'so']
# Negative Perplexity: 1973.496537866451
# Negative: ['unhappy', 'more', 'angry', 'beavers', 'slavery', 'and', 'crisis', 'hell', 'raping', 'kill']
# Negative Perplexity: 4978.331391733476
# Negative: ['boring', 'no', 'i', 'failed', 'my', 'hell', 'raping', 'kill', 'me', 'killed']
# Negative Perplexity: 3769.711074722615
# Negative: ['pity', 'less', 'thing', 'i', 'have', 'a', 'bad', 'raping', 'hell', 'yeah']
# Negative Perplexity: 1602.1313397426063
# Negative: ['dull', 'outside', 'i', 'have', 'raping', 'nick', 'said', 'hell', 'kill', 'chris']
# Negative Perplexity: 2942.392058410086
# Negative: ['screwed', 'hell', 'get', 'slavery', 'killed', 'the', 'raping', 'evil', 'is', 'sad']
# Negative Perplexity: 4471.5153420221195
# Negative: ['gross', 'now', 'kill', 'chris', 'wants', 'slavery', 'and', 'raping', 'tragedy', 'evil']
# Negative Perplexity: 5346.387463343387
# Negative: ['lazy', 'lucy', 'slavery', 'hell', 'is', 'dead', 'horrific', 'ended', 'early', 'to']
# Negative Perplexity: 4149.263530593734
# Negative: ['sadly', 'no', 'hate', 'crying', 'www', 'slavery', 'and', 'i', 'kill', 'myself']
# Negative Perplexity: 2849.7365212774107
# Negative: ['suffer', 'slavery', 'and', 'i', 'hate', 'sad', 'hell', 'kill', 'chris', 'raping']
# Negative Perplexity: 2712.131574758085
# Negative: ['disappointed', 'that', 'is', 'dead', 'slavery', 'killed', 'the', 'worst', 'start', 'raping']
# Negative Perplexity: 3449.974080114243
# Negative: ['horrible', 'my', 'shit', 'raping', 'slavery', 'tragedy', 'killed', 'the', 'worst', 'part']
# Negative Perplexity: 4538.964917383189
# Negative: ['thin', 'hell', 'is', 'killing', 'all', 'the', 'slavery', 'and', 'kill', 'myself']
# Negative Perplexity: 3466.6788410523855
# Negative: ['bad', 'slavery', 'raping', 'hell', 'yeah', 'i', 'hate', 'crying', 'for', 'me']
# Negative Perplexity: 2047.0746564018782
# Negative: ['vile', 'raping', 'hell', 'get', 'to', 'slavery', 'killed', 'the', 'worst', 'start']
# Negative Perplexity: 3706.3945049455438
# Negative: ['rundown', 'kill', 'me', 'raping', 'killed', 'the', 'hell', 'yeah', 'slavery', 'horrific']
# Negative Perplexity: 4242.927181653406
# Negative: ['frustrated', 'kill', 'me', 'cry', 'too', 'raping', 'slavery', 'and', 'tragedy', 'utter']
# Negative Perplexity: 4392.060673298327
# Negative: ['wretched', 'kill', 'myself', 'for', 'a', 'slavery', 'and', 'i', 'raping', 'hell']
# Negative Perplexity: 2492.0284054265917
# Negative: ['sour', 'sauce', 'killed', 'the', 'dead', 'kill', 'raping', 'evil', 'slavery', 'killing']
# Negative Perplexity: 5008.652882460801
# Negative: ['childish', 'hell', 'everybody', 'tonight', 'kill', 'raping', 'nick', 'said', 'slavery', 'evil']
# Negative Perplexity: 5278.534751691572
# Negative: ['clumsy', 'raping', 'killed', 'im', 'slavery', 'tragedy', 'evil', 'is', 'dead', 'tired']
# Negative Perplexity: 5350.677044901263
# Negative: ['mistake', 'not', 'bullshit', 'hell', 'slavery', 'kill', 'raping', 'nick', 'said', 'no']
# Negative Perplexity: 4940.0303023391825
# Negative: ['ruin', 'your', 'slavery', 'and', 'i', 'failed', 'on', 'the', 'shittiest', 'hell']
# Negative Perplexity: 2007.9779391280524
# Negative: ['cheap', 'raping', 'nick', 'slavery', 'tragedy', 'arms', 'for', 'hell', 'yeah', 'horrific']
# Negative Perplexity: 5109.55228542406
# Negative: ['low', 'concert', 'have', 'a', 'bad', 'slavery', 'kill', 'myself', 'hell', 'killing']
# Negative Perplexity: 3073.840204788353
# Negative: ['stupid', 'alarm', 'didnt', 'know', 'what', 'raping', 'nick', 'said', 'no', 'slavery']
# Negative Perplexity: 2993.0551380910697
# Negative: ['tired', 'all', 'the', 'shit', 'im', 'dead', 'raping', 'nick', 'said', 'kill']
# Negative Perplexity: 2750.6678660417438
# Negative: ['depressed', 'raping', 'hell', 'yeah', 'kill', 'killed', 'the', 'tragedy', 'arms', 'teddy']
# Negative Perplexity: 4814.659449294154
# Negative: ['slumdog', 'slavery', 'killed', 'tea', 'yet', 'again', 'evil', 'and', 'crisis', 'tragedy']
# Negative Perplexity: 4645.238444198199
# Negative: ['plain', 'white', 'hat', 'hell', 'raping', 'nick', 'slavery', 'horrific', 'ended', 'kill']
# Negative Perplexity: 5271.130834995169
# Negative: ['nausea', 'hell', 'get', 'to', 'the', 'shittiest', 'venue', 'in', 'raping', 'tragedy']
# Negative Perplexity: 2707.9435581606394
# Negative: ['static', 'kill', 'slavery', 'and', 'raping', 'killing', 'mee', 'horrific', 'evil', 'me']
# Negative Perplexity: 5709.468226545261
# Negative: ['exhaustion', 'raping', 'hell', 'yeah', 'killed', 'a', 'bitch', 'christ', 'horrific', 'ended']
# Negative Perplexity: 4471.898967232471
# Negative: ['pale', 'in', 'the', 'worst', 'dreams', 'make', 'slavery', 'and', 'kill', 'raping']
# Negative Perplexity: 3041.7172460619718
# Negative: ['weak', 'kill', 'myself', 'slavery', 'hell', 'yeah', 'i', 'evil', 'is', 'sad']
# Negative Perplexity: 3483.537401754895
# Negative: ['stiff', 'huhuhuhu', 'raping', 'nick', 'he', 'died', 'weeks', 'ago', 'hell', 'killing']
# Negative Perplexity: 4239.053418676676
# Negative: ['bum', 'is', 'a', 'bad', 'slavery', 'kill', 'me', 'sad', 'raping', 'tragedy']
# Negative Perplexity: 2857.5718876176675
# Negative: ['petty', 'images', 'kill', 'myself', 'raping', 'nick', 'he', 'is', 'killing', 'slavery']
# Negative Perplexity: 3829.452966400299
# Negative: ['faulty', 'slavery', 'kill', 'raping', 'hell', 'get', 'evil', 'and', 'killed', 'the']
# Negative Perplexity: 5346.298357041489
# Negative: ['idiots', 'hell', 'get', 'to', 'worst', 'raping', 'kill', 'chris', 'wants', 'to']
# Negative Perplexity: 3120.9049931256895
# Negative: ['wasted', 'slavery', 'kill', 'chris', 'wants', 'hell', 'yeah', 'killed', 'the', 'shittiest']
# Negative Perplexity: 4493.139403135702
# Negative: ['flat', 'slavery', 'and', 'raping', 'nick', 'said', 'he', 'hell', 'yeah', 'i']
# Negative Perplexity: 3363.524269333065
# Negative: ['sickness', 'kill', 'chris', 'rocker', 'hell', 'get', 'to', 'slavery', 'horrific', 'tragedy']
# Negative Perplexity: 4353.893541972259
# Negative: ['drain', 'slavery', 'and', 'crisis', 'raping', 'nick', 'kill', 'me', 'killed', 'hell']
# Negative Perplexity: 5145.607150487213
# Negative: ['depression', 'kill', 'slavery', 'hell', 'get', 'to', 'killed', 'a', 'raping', 'killing']
# Negative Perplexity: 4730.958461725358
# Negative: ['redundant', 'slavery', 'and', 'no', 'kill', 'chris', 'wants', 'to', 'raping', 'nick']
# Negative Perplexity: 3238.0011898587068
# Negative: ['unfortunate', 'slavery', 'hell', 'is', 'death', 'bed', 'killed', 'tea', 'so', 'sad']
# Negative Perplexity: 3806.6731119620276
# Negative: ['ruined', 'the', 'hell', 'is', 'killing', 'me', 'slavery', 'killed', 'tea', 'so']
# Negative Perplexity: 3472.8228667518742
# Negative: ['beaten', 'loads', 'of', 'hell', 'slavery', 'and', 'i', 'killed', 'the', 'dead']
# Negative Perplexity: 2664.9500647692353
# Negative: ['muddled', 'kill', 'chris', 'rocker', 'killed', 'raping', 'slavery', 'evil', 'me', 'sad']
# Negative Perplexity: 4750.013625864941
# Negative: ['exhausting', 'hell', 'is', 'a', 'bitch', 'in', 'raping', 'slavery', 'and', 'crisis']
# Negative Perplexity: 3314.202284807455
# Negative: ['rude', 'dont', 'have', 'a', 'bad', 'i', 'kill', 'chris', 'wants', 'to']
# Negative Perplexity: 1510.1230816412085
# Negative: ['woes', 'of', 'pain', 'in', 'the', 'raping', 'nick', 'said', 'he', 'was']
# Negative Perplexity: 2058.0158665722624
# Negative: ['dumping', 'they', 'are', 'you', 'killed', 'the', 'hell', 'yeah', 'i', 'hate']
# Negative Perplexity: 1312.6205472083209
# Negative: ['sorrythey', 'kill', 'chris', 'wants', 'to', 'worst', 'dreams', 'latelyhmmmm', 'slavery', 'raping']
# Negative Perplexity: 3852.171403645662
# Negative: ['painful', 'raping', 'nick', 'he', 'was', 'slavery', 'hell', 'killing', 'kill', 'me']
# Negative Perplexity: 4255.508486036129
# Negative: ['dumb', 'ass', 'actor', 'raping', 'kill', 'hell', 'killed', 'tea', 'that', 'slavery']
# Negative Perplexity: 5300.974854146079
# Negative: ['sorry', 'for', 'the', 'hell', 'raping', 'tragedy', 'utter', 'slavery', 'and', 'killed']
# Negative Perplexity: 2838.7646871386432
# Negative: ['stumble', 'back', 'to', 'go', 'to', 'raping', 'nick', 'he', 'slavery', 'kill']
# Negative Perplexity: 1739.127485829819
# Negative: ['cracked', 'on', 'the', 'worst', 'raping', 'nick', 'slavery', 'tragedy', 'utter', 'horrific']
# Negative Perplexity: 3333.177497543671
# Negative: ['fails', 'me', 'sad', 'disappointed', 'with', 'slavery', 'killed', 'im', 'not', 'bad']
# Negative Perplexity: 2615.0464734925677
# Negative: ['mistakes', 'arent', 'enough', 'to', 'go', 'to', 'kill', 'chris', 'to', 'killed']
# Negative Perplexity: 1878.1609168320792
# Negative: ['crumbling', 'kill', 'myself', 'hell', 'is', 'a', 'bitch', 'and', 'killed', 'the']
# Negative Perplexity: 3068.8884246403304
# Negative: ['unfortunately', 'link', 'and', 'slavery', 'and', 'i', 'hate', 'kill', 'chris', 'brown']
# Negative Perplexity: 2289.088400674665
# Negative: ['dry', 'spot', 'in', 'the', 'shittiest', 'hell', 'yeah', 'slavery', 'tragedy', 'kill']
# Negative Perplexity: 3097.2800106534924
# Negative: ['failing', 'slavery', 'and', 'i', 'hate', 'it', 'was', 'tragedy', 'hell', 'kill']
# Negative Perplexity: 1714.6115499788725
# Negative: ['pile', 'up', 'and', 'slavery', 'and', 'hell', 'raping', 'nick', 'said', 'tragedy']
# Negative Perplexity: 4095.8998353252146
# Negative: ['hurts', 'i', 'hate', 'the', 'shittiest', 'venue', 'hell', 'killed', 'raping', 'horrific']
# Negative Perplexity: 3391.1908534929917
# Negative: ['failsnot', 'hell', 'yeah', 'i', 'failed', 'her', 'kill', 'slavery', 'and', 'crisis']
# Negative Perplexity: 3372.1305156529966
# Negative: ['fault', 'no', 'one', 'of', 'hell', 'raping', 'tragedy', 'kill', 'myself', 'evil']
# Negative Perplexity: 3232.1709013785157
# Negative: ['terrible', 'programme', 'hell', 'yeah', 'i', 'have', 'to', 'kill', 'chris', 'to']
# Negative Perplexity: 1430.2587602898761
# Negative: ['badly', 'slavery', 'killed', 'a', 'raping', 'kill', 'myself', 'tragedy', 'evil', 'is']
# Negative Perplexity: 5729.194233690871
# Negative: ['fail', 'of', 'horrible', 'my', 'slavery', 'kill', 'me', 'raping', 'nick', 'hell']
# Negative Perplexity: 4836.356871556382
# Negative: ['sack', 'slavery', 'and', 'i', 'failed', 'her', 'hell', 'raping', 'killed', 'tea']
# Negative Perplexity: 3263.79479040348
# Negative: ['dump', 'my', 'raping', 'killed', 'tea', 'yet', 'ill', 'die', 'tomorrow', 'kill']
# Negative Perplexity: 4471.607180976826
# Negative: ['unpleasant', 'surprises', 'kill', 'slavery', 'tragedy', 'hell', 'yeah', 'raping', 'nick', 'paid']
# Negative Perplexity: 5066.752090260205
# Negative: ['empty', 'were', 'all', 'the', 'shittiest', 'venue', 'raping', 'kill', 'me', 'killing']
# Negative Perplexity: 3068.3628260675923
# Negative: ['failure', 'then', 'shit', 'died', 'weeks', 'ago', 'slavery', 'and', 'hell', 'raping']
# Negative Perplexity: 4463.973278698139
# Negative: ['ill', 'die', 'time', 'raping', 'kill', 'chris', 'brown', 'go', 'to', 'slavery']
# Negative Perplexity: 3380.380585495397
# Negative: ['bloated', 'soo', 'difficult', 'no', 'kill', 'chris', 'raping', 'tragedy', 'slavery', 'hell']
# Negative Perplexity: 5286.84323233765
# Negative: ['idiot', 'damn', 'sad', 'raping', 'nick', 'said', 'kill', 'chris', 'to', 'tragedy']
# Negative Perplexity: 4686.7768924527345
# Negative: ['costly', 'raping', 'hell', 'my', 'killed', 'slavery', 'kill', 'tragedy', 'horrific', 'shittiest']
# Negative Perplexity: 6563.12892591505
# Negative: ['crap', 'the', 'hell', 'my', 'slavery', 'and', 'i', 'killed', 'a', 'tragedy']
# Negative Perplexity: 3175.5337273027553
# Negative: ['gutted', 'when', 'you', 'hate', 'raping', 'kill', 'chris', 'wants', 'to', 'hell']
# Negative Perplexity: 3106.0510835434898
# Negative: ['dumped', 'by', 'myself', 'in', 'the', 'worst', 'start', 'slavery', 'and', 'raping']
# Negative Perplexity: 2417.095772383376
# Negative: ['mis', 'with', 'the', 'worst', 'raping', 'nick', 'paid', 'weekly', 'webcomic', 'slavery']
# Negative Perplexity: 3176.9976543340176
# Negative: ['vomiting', 'is', 'a', 'bad', 'slavery', 'kill', 'me', 'sad', 'hell', 'horrific']
# Negative Perplexity: 2858.1057178515953
# Negative: ['failed', 'on', 'the', 'worst', 'part', 'of', 'my', 'hell', 'kill', 'raping']
# Negative Perplexity: 2014.341991063429
# Negative: ['crappy', 'sunday', 'sunday', 'sunday', 'sunday', 'sunday', 'slavery', 'raping', 'hell', 'kill']
# Negative Perplexity: 2265.3927666582103
# Negative: ['loss', 'weekend', 'i', 'have', 'a', 'raping', 'slavery', 'killed', 'the', 'worst']
# Negative Perplexity: 1889.2906990234735
# Negative: ['exhausted', 'is', 'a', 'horrible', 'coldflu', 'has', 'a', 'bad', 'slavery', 'kill']
# Negative Perplexity: 2360.242818752223
# Negative: ['fumbled', 'kill', 'me', 'hell', 'is', 'raping', 'nick', 'he', 'killed', 'tea']
# Negative Perplexity: 4797.493554565911
# Negative: ['dire', 'of', 'the', 'worst', 'slavery', 'killed', 'a', 'bitch', 'loljkmines', 'tragedy']
# Negative Perplexity: 2985.4737114769487
# Negative: ['ignore', 'the', 'worst', 'dreams', 'ever', 'hell', 'raping', 'kill', 'me', 'sad']
# Negative Perplexity: 3885.3277730204677
# Negative: ['sucked', 'raping', 'hell', 'yeah', 'i', 'kill', 'me', 'slavery', 'killed', 'tragedy']
# Negative Perplexity: 4342.70437387575
# Negative: ['rushed', 'to', 'the', 'shit', 'died', 'sorry', 'for', 'a', 'kill', 'me']
# Negative Perplexity: 1734.2210835326168
# Negative: ['choked', 'kill', 'raping', 'nick', 'paid', 'weekly', 'so', 'i', 'slavery', 'and']
# Negative Perplexity: 3632.339197341044
# Negative: ['irritated', 'when', 'i', 'am', 'raping', 'kill', 'slavery', 'killing', 'all', 'killed']
# Negative Perplexity: 2804.1511852386593
# Negative: ['abandon', 'us', 'hell', 'yeah', 'killed', 'the', 'dead', 'slavery', 'kill', 'myself']
# Negative Perplexity: 4194.171309495974
# Negative: ['drag', 'even', 'kill', 'me', 'raping', 'slavery', 'and', 'i', 'hate', 'sad']
# Negative Perplexity: 2442.503507381552
# Negative: ['messy', 'kill', 'me', 'sad', 'raping', 'slavery', 'hell', 'horrific', 'killed', 'the']
# Negative Perplexity: 4566.949659730676
# Negative: ['scam', 'hell', 'yeah', 'i', 'failed', 'at', 'work', 'kill', 'myself', 'killed']
# Negative Perplexity: 2616.464352316638
# Negative: ['starving', 'artists', 'all', 'day', 'raping', 'nick', 'to', 'worst', 'dreams', 'latelyhmmmm']
# Negative Perplexity: 3271.5360423536345
# Negative: ['blind', 'slavery', 'raping', 'nick', 'paid', 'work', 'on', 'killed', 'the', 'hell']
# Negative Perplexity: 3302.733150063008
# Negative: ['warped', 'slavery', 'kill', 'myself', 'in', 'raping', 'killed', 'the', 'shittiest', 'venue']
# Negative Perplexity: 4396.330974706511
# Negative: ['doomed', 'killed', 'tea', 'yet', 'i', 'kill', 'raping', 'nick', 'he', 'is']
# Negative Perplexity: 3489.4525492438042
# Negative: ['beige', 'kill', 'chris', 'to', 'worst', 'part', 'of', 'the', 'dead', 'slavery']
# Negative Perplexity: 2484.8998409145797
# Negative: ['distracted', 'kill', 'raping', 'killed', 'the', 'dead', 'evil', 'and', 'crisis', 'i']
# Negative Perplexity: 4407.234886797015
# Negative: ['stink', 'kill', 'slavery', 'raping', 'nick', 'paid', 'weekly', 'killed', 'the', 'dead']
# Negative Perplexity: 4359.659722052739
# Negative: ['heavy', 'makeup', 'hell', 'everybody', 'see', 'kill', 'chris', 'raping', 'killed', 'the']
# Negative Perplexity: 4598.414262408078
# Negative: ['slow', 'admit', 'lol', 'i', 'raping', 'nick', 'he', 'slavery', 'hell', 'yeah']
# Negative Perplexity: 3620.917968662187
# Negative: ['drunk', 'guy', 'with', 'the', 'worst', 'start', 'off', 'the', 'raping', 'kill']
# Negative Perplexity: 2544.2597106143726
# Negative: ['vacuum', 'raping', 'slavery', 'hell', 'yeah', 'i', 'have', 'to', 'tragedy', 'killed']
# Negative Perplexity: 2022.4005402676717
# Negative: ['cold', 'kill', 'me', 'raping', 'nick', 'slavery', 'killed', 'im', 'not', 'bad']
# Negative Perplexity: 3202.309096761304
# Negative: ['sore', 'head', 'hurts', 'sad', 'day', 'raping', 'nick', 'paid', 'slavery', 'killed']
# Negative Perplexity: 4130.232389453906
# Negative: ['annoyed', 'slavery', 'kill', 'me', 'hell', 'yeah', 'killed', 'im', 'tired', 'but']
# Negative Perplexity: 3652.801950491894
# Negative: ['hated', 'kill', 'myself', 'slavery', 'and', 'i', 'hate', 'it', 'was', 'tragedy']
# Negative Perplexity: 1600.133368091862
# Negative: ['embarrassing', 'kill', 'me', 'sad', 'raping', 'nick', 'slavery', 'hell', 'evil', 'and']
# Negative Perplexity: 4566.949735239396
# Negative: ['messed', 'hell', 'is', 'death', 'say', 'kill', 'myself', 'killed', 'the', 'raping']
# Negative Perplexity: 4717.536894394704
# Negative: ['drown', 'kill', 'chris', 'brown', 'raping', 'nick', 'slavery', 'and', 'crisis', 'i']
# Negative Perplexity: 4637.5293351665005
# Negative: ['overrun', 'kill', 'me', 'slavery', 'raping', 'nick', 'said', 'no', 'evil', 'is']
# Negative Perplexity: 4765.130031553684
# Negative: ['fools', 'raping', 'nick', 'said', 'no', 'hell', 'yeah', 'i', 'kill', 'chris']
# Negative Perplexity: 3663.424124572978
# Negative: ['evil', 'and', 'raping', 'nick', 'paid', 'me', 'hell', 'killed', 'a', 'slavery']
# Negative Perplexity: 5069.743305115914
# Negative: ['headache', 'and', 'no', 'hate', 'it', 'was', 'kill', 'chris', 'rocker', 'slavery']
# Negative Perplexity: 2080.34399549968
# Negative: ['cardboard', 'cup', 'im', 'pissed', 'both', 'miserable', 'slavery', 'hell', 'yeah', 'i']
# Negative Perplexity: 3212.8319307973284
# Negative: ['sick', 'again', 'i', 'hate', 'it', 'was', 'raping', 'kill', 'hell', 'killing']
# Negative Perplexity: 2124.294228102738
# Negative: ['vain', 'of', 'the', 'dead', 'hell', 'raping', 'kill', 'slavery', 'horrific', 'killing']
# Negative Perplexity: 3776.6480590239844
# Negative: ['shame', 'slavery', 'killed', 'tea', 'that', 'i', 'have', 'to', 'worst', 'kill']
# Negative Perplexity: 1739.9085470730597
# Negative: ['terribly', 'slow', 'jams', 'slavery', 'and', 'kill', 'raping', 'tragedy', 'arms', 'legs']
# Negative Perplexity: 4970.523774136815
# Negative: ['stupidbut', 'yet', 'i', 'hate', 'it', 'kill', 'me', 'hell', 'raping', 'slavery']
# Negative Perplexity: 2829.7510884148405
# Negative: ['lacking', 'on', 'my', 'slavery', 'kill', 'chris', 'rocker', 'horrific', 'tragedy', 'arms']
# Negative Perplexity: 3585.683841686742
# Negative: ['mean', 'i', 'have', 'a', 'sad', 'raping', 'killed', 'a', 'bad', 'hell']
# Negative Perplexity: 1636.3383863311867
# Negative: ['false', 'start', 'slavery', 'raping', 'nick', 'to', 'worst', 'hell', 'killed', 'kill']
# Negative Perplexity: 5376.611458009636
# Negative: ['bombed', 'kill', 'chris', 'brown', 'band', 'or', 'something', 'slavery', 'hell', 'killing']
# Negative Perplexity: 4289.895673875457
# Negative: ['grave', 'raping', 'nick', 'to', 'go', 'slavery', 'killed', 'the', 'hell', 'yeah']
# Negative Perplexity: 2685.4243926717068
# Negative: ['drowned', 'kill', 'myself', 'slavery', 'and', 'crisis', 'raping', 'nick', 'paid', 'weekly']
# Negative Perplexity: 4639.126933503694
# Negative: ['hurt', 'again', 'i', 'hate', 'slavery', 'raping', 'hell', 'killed', 'a', 'kill']
# Negative Perplexity: 3796.1010182221703
# Negative: ['boringcome', 'kill', 'myself', 'in', 'my', 'death', 'bed', 'raping', 'slavery', 'tragedy']
# Negative Perplexity: 3479.595434012802
# Negative: ['misses', 'raping', 'nick', 'said', 'no', 'slavery', 'kill', 'me', 'sad', 'hell']
# Negative Perplexity: 4274.184094686707
# Negative: ['cracks', 'slavery', 'hell', 'everybody', 'is', 'a', 'kill', 'me', 'horrific', 'tragedy']
# Negative Perplexity: 3868.164961710661
# Negative: ['nasty', 'id', 'doubt', 'concert', 'i', 'have', 'slavery', 'and', 'crisis', 'kill']
# Negative Perplexity: 2973.645398127113
# Negative: ['disheartening', 'kill', 'raping', 'nick', 'he', 'died', 'in', 'slavery', 'and', 'crisis']
# Negative Perplexity: 4495.525567762935
# Negative: ['nightmare', 'hell', 'everybody', 'and', 'raping', 'kill', 'chris', 'rocker', 'horrific', 'tragedy']
# Negative Perplexity: 5328.270512683264
# Negative: ['errors', 'hell', 'everybody', 'see', 'slavery', 'raping', 'horrific', 'killed', 'im', 'not']
# Negative Perplexity: 3884.7807282768135
# Negative: ['distant', 'hell', 'get', 'a', 'slavery', 'kill', 'myself', 'in', 'the', 'raping']
# Negative Perplexity: 2518.3387945098116
# Negative: ['severe', 'storm', 'www', 'poor', 'kill', 'raping', 'nick', 'slavery', 'killed', 'the']
# Negative Perplexity: 4115.430650965756
# Negative: ['ridiculous', 'kill', 'myself', 'slavery', 'and', 'i', 'have', 'a', 'bitch', 'in']
# Negative Perplexity: 1368.0498948631498
# Negative: ['hole', 'slavery', 'hell', 'my', 'killed', 'the', 'dead', 'raping', 'nick', 'paid']
# Negative Perplexity: 4410.374502670184
# Negative: ['error', 'killed', 'the', 'shit', 'im', 'raping', 'nick', 'said', 'kill', 'hell']
# Negative Perplexity: 4215.7447106040745
# Negative: ['illiterate', 'killed', 'tea', 'yet', 'to', 'go', 'to', 'raping', 'kill', 'me']
# Negative Perplexity: 2032.526553969404
# Negative: ['stuck', 'in', 'raping', 'nick', 'to', 'hell', 'kill', 'killed', 'tea', 'that']
# Negative Perplexity: 4531.393726018389
# Negative: ['wrong', 'with', 'the', 'dead', 'tired', 'slavery', 'hell', 'killed', 'a', 'bad']
# Negative Perplexity: 2764.24781600567
# Negative: ['bastard', 'killed', 'a', 'bad', 'kill', 'me', 'hell', 'yeah', 'i', 'tragedy']
# Negative Perplexity: 3384.0685611280733
# Negative: ['ick', 'slavery', 'and', 'i', 'failed', 'for', 'me', 'killed', 'the', 'dead']
# Negative Perplexity: 1868.7369493767362
# Negative: ['bullshit', 'hell', 'is', 'sad', 'kill', 'chris', 'wants', 'to', 'worst', 'raping']
# Negative Perplexity: 3431.7287052621705
# Negative: ['hate', 'sad', 'day', 'raping', 'nick', 'he', 'died', 'sorry', 'to', 'slavery']
# Negative Perplexity: 3188.7824563583395
# Negative: ['seperate', 'hell', 'yeah', 'slavery', 'and', 'i', 'raping', 'kill', 'myself', 'evil']
# Negative Perplexity: 3681.3895581299603
# Negative: ['death', 'ill', 'be', 'a', 'sad', 'kill', 'myself', 'in', 'the', 'hell']
# Negative Perplexity: 1289.0029819867884
# Negative: ['needles', 'or', 'something', 'for', 'a', 'sad', 'hell', 'killed', 'the', 'slavery']
# Negative Perplexity: 2152.215986181344
# Negative: ['spoiled', 'kill', 'me', 'cry', 'whenever', 'raping', 'tragedy', 'slavery', 'horrific', 'killed']
# Negative Perplexity: 4978.666880852412
# Negative: ['grey', 'slavery', 'and', 'raping', 'nick', 'kill', 'me', 'sad', 'killing', 'hell']
# Negative Perplexity: 4615.593784900046
# Negative: ['down', 'with', 'my', 'slavery', 'raping', 'tragedy', 'hell', 'killed', 'im', 'tired']
# Negative Perplexity: 3281.132791307317
# Negative: ['hazing', 'raping', 'hell', 'yeah', 'tragedy', 'kill', 'killed', 'the', 'worst', 'part']
# Negative Perplexity: 4623.080650052703
# Negative: ['traitor', 'to', 'kill', 'chris', 'brown', 'go', 'to', 'slavery', 'and', 'crisis']
# Negative Perplexity: 2819.938272472388
# Negative: ['hating', 'raping', 'nick', 'to', 'the', 'hell', 'kill', 'killed', 'slavery', 'evil']
# Negative Perplexity: 3475.8186171806947
# Negative: ['avoid', 'parking', 'kill', 'me', 'hell', 'get', 'to', 'raping', 'slavery', 'and']
# Negative Perplexity: 3923.851197979565
# Negative: ['broken', 'hands', 'the', 'worst', 'part', 'of', 'my', 'slavery', 'and', 'raping']
# Negative Perplexity: 2739.8635119559244
# Negative: ['hurtsbut', 'hell', 'is', 'killing', 'mee', 'kill', 'chris', 'to', 'killed', 'im']
# Negative Perplexity: 4531.961455873901
# Negative: ['hack', 'studio', 'project', 'in', 'a', 'sad', 'hell', 'yeah', 'raping', 'nick']
# Negative Perplexity: 2698.247820078291
# Negative: ['cheat', 'hell', 'yeah', 'slavery', 'and', 'kill', 'me', 'sad', 'horrific', 'ended']
# Negative Perplexity: 4139.70245974384
# Negative: ['coma', 'i', 'have', 'no', 'slavery', 'kill', 'me', 'cry', 'why', 'did']
# Negative Perplexity: 1935.4962962377224
# Negative: ['drained', 'it', 'hurts', 'i', 'have', 'raping', 'slavery', 'and', 'crisis', 'hell']
# Negative Perplexity: 2878.7280570886182
# Negative: ['tiring', 'pl', 'hell', 'yeah', 'i', 'hate', 'it', 'killed', 'a', 'slavery']
# Negative Perplexity: 2498.1914722407105
# Negative: ['nowhere', 'raping', 'slavery', 'and', 'kill', 'me', 'killed', 'tea', 'yet', 'ill']
# Negative Perplexity: 4613.35949947333
# Negative: ['flu', 'kill', 'raping', 'nick', 'said', 'he', 'is', 'killing', 'all', 'hell']
# Negative Perplexity: 3583.899918443415
# Negative: ['tiredddd', 'raping', 'hell', 'yeah', 'i', 'hate', 'it', 'killed', 'tea', 'that']
# Negative Perplexity: 2464.4134837344177
# Negative: ['damage', 'killed', 'tea', 'so', 'much', 'i', 'slavery', 'tragedy', 'arms', 'for']
# Negative Perplexity: 3012.7297814523754
# Negative: ['exit', 'row', 'people', 'slavery', 'and', 'kill', 'me', 'killed', 'raping', 'evil']
# Negative Perplexity: 5148.338853406309
# Negative: ['angry', 'than', 'i', 'am', 'raping', 'slavery', 'hell', 'killed', 'im', 'tired']
# Negative Perplexity: 2724.290978012338
# Negative: ['trap', 'lets', 'go', 'to', 'kill', 'raping', 'nick', 'paid', 'slavery', 'and']
# Negative Perplexity: 2736.618548483252
# Negative: ['grind', 'raping', 'nick', 'paid', 'work', 'on', 'the', 'shittiest', 'kill', 'me']
# Negative Perplexity: 2394.6101655454554
# Negative: ['fallen', 'raping', 'nick', 'paid', 'in', 'the', 'dead', 'hell', 'kill', 'me']
# Negative Perplexity: 2805.7868066999813
# Negative: ['insanity', 'is', 'killing', 'me', 'slavery', 'and', 'hell', 'kill', 'raping', 'evil']
# Negative Perplexity: 4650.2816018716285
# Negative: ['frustrations', 'hell', 'everybody', 'and', 'i', 'slavery', 'and', 'i', 'hate', 'kill']
# Negative Perplexity: 1835.9555885087357
# Negative: ['dust', 'gone', 'to', 'be', 'raping', 'kill', 'hell', 'killing', 'me', 'horrific']
# Negative Perplexity: 3059.1070676617537
# Negative: ['horrific', 'slavery', 'hell', 'yeah', 'i', 'raping', 'killed', 'the', 'shittiest', 'venue']
# Negative Perplexity: 3718.369613069963
# Negative: ['fell', 'slavery', 'kill', 'myself', 'raping', 'nick', 'to', 'worst', 'hell', 'evil']
# Negative Perplexity: 5376.76562882583
# Negative: ['dying', 'watering', 'slavery', 'and', 'raping', 'nick', 'kill', 'me', 'sad', 'tragedy']
# Negative Perplexity: 4306.253712738656
# Negative: ['losing', 'much', 'i', 'have', 'a', 'slavery', 'and', 'hell', 'killed', 'im']
# Negative Perplexity: 1931.668941632846
# Negative: ['blanks', 'raping', 'killed', 'a', 'bitch', 'and', 'slavery', 'killing', 'it', 'was']
# Negative Perplexity: 3358.6822955017205
# Negative: ['deleting', 'kill', 'chris', 'to', 'worst', 'part', 'of', 'my', 'hell', 'raping']
# Negative Perplexity: 3029.7442325114635
# Negative: ['shattered', 'by', 'the', 'worst', 'part', 'of', 'slavery', 'raping', 'nick', 'kill']
# Negative Perplexity: 3311.702718963777
# Negative: ['ruins', 'kill', 'slavery', 'and', 'no', 'raping', 'nick', 'to', 'hell', 'killing']
# Negative Perplexity: 4518.225229772537
# Negative: ['fake', 'kristen', 'kill', 'chris', 'rocker', 'hell', 'killed', 'the', 'worst', 'slavery']
# Negative Perplexity: 4487.7390083497385
# Negative: ['confuse', 'slavery', 'raping', 'hell', 'is', 'kill', 'chris', 'rocker', 'evil', 'and']
# Negative Perplexity: 5316.137001890478
# Negative: ['regrets', 'educational', 'cartoons', 'like', 'shit', 'raping', 'killed', 'tea', 'la', 'the']
# Negative Perplexity: 3960.1281338500166
# Negative: ['forgotten', 'how', 'to', 'kill', 'chris', 'rocker', 'tragedy', 'raping', 'hell', 'killed']
# Negative Perplexity: 3951.159951174396
# Negative: ['void', 'kill', 'chris', 'to', 'slavery', 'hell', 'killing', 'it', 'killed', 'im']
# Negative Perplexity: 5421.774783709838
# Negative: ['sorryconfused', 'kill', 'me', 'cry', 'legs', 'but', 'i', 'raping', 'tragedy', 'slavery']
# Negative Perplexity: 3112.7621779162732
# Negative: ['bomb', 'haha', 'raping', 'kill', 'slavery', 'tragedy', 'arms', 'teddy', 'killed', 'tea']
# Negative Perplexity: 5280.227040123892
# Negative: ['lose', 'weighgym', 'kill', 'raping', 'nick', 'slavery', 'and', 'crisis', 'tragedy', 'killed']
# Negative Perplexity: 5326.969154502979
# Negative: ['dense', 'slavery', 'kill', 'chris', 'raping', 'killing', 'hell', 'evil', 'killed', 'tea']
# Negative Perplexity: 6055.983939662899
# Negative: ['starved', 'slavery', 'kill', 'chris', 'to', 'hell', 'killing', 'me', 'killed', 'im']
# Negative Perplexity: 4844.5108453784605
# Negative: ['nazi', 'yep', 'shes', 'a', 'sad', 'raping', 'hell', 'kill', 'me', 'killed']
# Negative Perplexity: 3882.588601909578
# Negative: ['retreating', 'slavery', 'raping', 'kill', 'me', 'evil', 'and', 'crisis', 'hell', 'horrific']
# Negative Perplexity: 5515.321103649406
# Negative: ['victim', 'of', 'the', 'dead', 'hell', 'raping', 'slavery', 'tragedy', 'horrific', 'shittiest']
# Negative Perplexity: 3776.593785545623
# Negative: ['shortage', 'slavery', 'and', 'no', 'hell', 'get', 'raping', 'kill', 'chris', 'brown']
# Negative Perplexity: 4148.719062604559
# Negative: ['famine', 'is', 'dead', 'slavery', 'killed', 'raping', 'nick', 'said', 'hell', 'evil']
# Negative Perplexity: 5318.96261644167
# Negative: ['cancel', 'kill', 'raping', 'killed', 'the', 'worst', 'dreams', 'latelyhmmmm', 'evil', 'and']
# Negative Perplexity: 4487.158637238873
# Negative: ['drunken', 'rambling', 'slavery', 'kill', 'hell', 'my', 'killed', 'the', 'worst', 'start']
# Negative Perplexity: 4538.183199527912
# Negative: ['asleep', 'on', 'my', 'slavery', 'and', 'i', 'hate', 'sad', 'kill', 'myself']
# Negative Perplexity: 1721.401573028883
# Negative: ['missing', 'lost', 'the', 'hell', 'is', 'dead', 'kill', 'me', 'killed', 'the']
# Negative Perplexity: 3376.9561370360198
# Negative: ['mad', 'cup', 'of', 'my', 'kill', 'myself', 'raping', 'nick', 'paid', 'weekly']
# Negative Perplexity: 2918.735039966476
# Negative: ['zombie', 'slavery', 'raping', 'tragedy', 'hell', 'my', 'evil', 'kill', 'myself', 'killing']
# Negative Perplexity: 6125.637392613504
# Negative: ['casualty', 'now', 'im', 'not', 'slavery', 'hell', 'kill', 'myself', 'in', 'killing']
# Negative Perplexity: 2738.2626927878623
# Negative: ['delete', 'the', 'worst', 'start', 'off', 'to', 'kill', 'raping', 'tragedy', 'slavery']
# Negative Perplexity: 3131.1329809576114
# Negative: ['sleep', 'slavery', 'kill', 'raping', 'nick', 'said', 'hell', 'evil', 'and', 'tragedy']
# Negative Perplexity: 5718.141760957209
# Negative: ['awfully', 'longyuck', 'very', 'sick', 'for', 'a', 'kill', 'me', 'hell', 'slavery']
# Negative Perplexity: 3008.641811584691
# Negative: ['hurry', 'up', 'raping', 'nick', 'to', 'hell', 'kill', 'chris', 'wants', 'killing']
# Negative Perplexity: 4833.043491443508
# Negative: ['awkwardness', 'hell', 'my', 'slavery', 'raping', 'horrific', 'killed', 'tea', 'la', 'semarreta']
# Negative Perplexity: 5331.836499738012
# Negative: ['rambling', 'in', 'the', 'worst', 'start', 'slavery', 'hell', 'killing', 'mee', 'tragedy']
# Negative Perplexity: 3223.27966946799
# Negative: ['sitcom', 'kill', 'me', 'hell', 'get', 'a', 'raping', 'horrific', 'killed', 'tea']
# Negative Perplexity: 4094.211935788566
# Negative: ['rejected', 'by', 'raping', 'slavery', 'killed', 'tea', 'i', 'tragedy', 'arms', 'legs']
# Negative Perplexity: 4846.982111690453
# Negative: ['quit', 'weird', 'strange', 'slavery', 'killed', 'a', 'kill', 'raping', 'killing', 'me']
# Negative Perplexity: 4788.133821733985
# Negative: ['roach', 'hell', 'everybody', 'is', 'killing', 'me', 'sad', 'raping', 'slavery', 'kill']
# Negative Perplexity: 3850.6555156565364
